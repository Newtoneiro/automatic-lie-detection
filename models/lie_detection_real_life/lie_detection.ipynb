# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
from utils import get_cuda_info

get_cuda_info()
# Out:
# PyTorch version: 2.5.1+cu118
# **********
# _CUDA version:
# CUDA version:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Wed_Oct_30_01:18:48_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.85
# Build cuda_12.6.r12.6/compiler.35059454_0
#
# **********
# CUDNN version: 90100
# Available GPU devices: 1
# Device Name: NVIDIA GeForce RTX 4070 Ti SUPER

# %% [markdown]
# ## Zdobycie danych

# %%
import numpy as np

LANDMARK_INDEXES = np.load(os.path.join('..', '..', 'data', 'landmarks', 'combined_selected_points_emotions.npy'))

# %%
from utils import load_data, get_selected_landmarks

all_data, all_labels = load_data('real_life_deception_detection')
all_data = get_selected_landmarks(all_data, LANDMARK_INDEXES)

# %% [markdown]
# ## Preprocessing danych

# %%
from utils import preprocess_data

X_train, X_val, X_test, y_train, y_val, y_test = preprocess_data(all_data, all_labels, binarize_labels=False)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([84, 2125, 154, 2])
# torch.Size([84])

# %%
from utils import get_class_distribution

get_class_distribution(all_labels)
# Out:
# ===> Class distribution <===
# 0: 60
# 1: 61
# =============><=============

# %% [markdown]
# # MODEL TORCH

# %% [markdown]
# ## Zbudowanie modelu ekstrakcji cech

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class LieClassifier(nn.Module):
    def __init__(self, num_landmarks):
        super(LieClassifier, self).__init__()
        
        self.conv1 = nn.Conv1d(in_channels=2, out_channels=32, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2)
        
        # Compute conv_output_size dynamically
        self.conv_output_size = self._get_conv_output_size(num_landmarks)
        
        self.lstm = nn.LSTM(input_size=self.conv_output_size, hidden_size=128, 
                            batch_first=True, bidirectional=True)
        
        self.attn = nn.Linear(256, 1)
        self.fc1 = nn.Linear(256, 64)
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(64, 1)

        self._init_weights()

    def _get_conv_output_size(self, num_landmarks):
        # Dummy input: (batch=1, channels=2, landmarks)
        x = torch.zeros(1, 2, num_landmarks)
        x = self.pool1(F.relu(self.conv1(x)))  # -> (1, 32, L1)
        x = self.pool2(F.relu(self.conv2(x)))  # -> (1, 64, L2)
        return x.numel()  # Flattened size: channels * length

    def _init_weights(self):
        for name, param in self.named_parameters():
            if 'weight' in name:
                nn.init.xavier_normal_(param)
            elif 'bias' in name:
                nn.init.constant_(param, 0.1)

    def forward(self, x):
        # x: (batch, frames, landmarks, coordinates)
        batch_size, frames, landmarks, coordinates = x.shape
        
        x = x.view(-1, landmarks, coordinates)  # (batch*frames, landmarks, 2)
        x = x.permute(0, 2, 1)  # (batch*frames, 2, landmarks)
        
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))

        x = x.view(batch_size, frames, -1)  # Flatten: (batch, frames, conv_output_size)

        x, _ = self.lstm(x)
        attn_weights = torch.softmax(self.attn(x), dim=1)
        x = (x * attn_weights).sum(dim=1)

        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        return self.fc2(x)  # Raw logits

# %%
from torch.optim import Adam

model = LieClassifier(num_landmarks=len(LANDMARK_INDEXES))
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pos_weight = torch.tensor([(len(y_train) - y_train.sum()) / y_train.sum()]).to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# ## Trening modelu

# %%
from torch.utils.tensorboard import SummaryWriter

RUNS_FOLDER_PATH = os.path.abspath('runs')
writer_path = os.path.join('runs', 'torch_lstm', 'lie_classifier')
writer = SummaryWriter(writer_path)

# %% [markdown]
# ### Diagnostyka

# %%
from utils.model_functions import overfit_model

writer_diag_path = os.path.join('runs', 'torch_lstm', 'lie_classifier_overfit')
writer_diag = SummaryWriter(writer_diag_path)
model_diag = LieClassifier()
pos_weight_diag = torch.tensor([(len(y_train) - y_train.sum()) / y_train.sum()]).to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
criterion_diag = nn.BCEWithLogitsLoss(pos_weight=pos_weight_diag)
optimizer_diag = Adam(model.parameters(), lr=1e-3)

overfit_model(model_diag, criterion_diag, optimizer_diag, X_train, y_train, batch_size=8, writer=writer_diag, epochs=200)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
from utils.model_functions import train_torch_model_binary

train_torch_model_binary(model, criterion, optimizer, X_train, y_train, X_val, y_val, writer=writer, batch_size=32, unbalanced=True, show_prediction_stats=False)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1912                                    Loss        : 0.7139
# Accuracy    : 0.4881                                    Accuracy    : 0.5000
# Precision   : 0.4875                                    Precision   : 0.2500
# Recall      : 0.4881                                    Recall      : 0.5000
# F1 Score    : 0.4822                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 2
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.0798                                    Loss        : 0.7167
# Accuracy    : 0.5952                                    Accuracy    : 0.5000
# Precision   : 0.5938                                    Precision   : 0.2500
# Recall      : 0.5732                                    Recall      : 0.5000
# F1 Score    : 0.5593                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 3
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.2107                                    Loss        : 0.7082
# Accuracy    : 0.4167                                    Accuracy    : 0.5000
# Precision   : 0.4112                                    Precision   : 0.2500
# Recall      : 0.4144                                    Recall      : 0.5000
# F1 Score    : 0.4099                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 4
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.0759                                    Loss        : 0.7082
# Accuracy    : 0.5595                                    Accuracy    : 0.5000
# Precision   : 0.5361                                    Precision   : 0.2500
# Recall      : 0.5357                                    Recall      : 0.5000
# F1 Score    : 0.5358                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 5
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1376                                    Loss        : 0.7079
# Accuracy    : 0.5595                                    Accuracy    : 0.5000
# Precision   : 0.5804                                    Precision   : 0.2500
# Recall      : 0.5718                                    Recall      : 0.5000
# F1 Score    : 0.5518                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 6
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1666                                    Loss        : 0.7055
# Accuracy    : 0.5357                                    Accuracy    : 0.5000
# Precision   : 0.5232                                    Precision   : 0.2500
# Recall      : 0.5212                                    Recall      : 0.5000
# F1 Score    : 0.5159                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 7
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1561                                    Loss        : 0.7039
# Accuracy    : 0.5595                                    Accuracy    : 0.3889
# Precision   : 0.5531                                    Precision   : 0.3393
# Recall      : 0.5521                                    Recall      : 0.3889
# F1 Score    : 0.5518                                    F1 Score    : 0.3378
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.1111                                    FP Rate     : 0.3333
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 8
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.2275                                    Loss        : 0.7021
# Accuracy    : 0.4167                                    Accuracy    : 0.6667
# Precision   : 0.4267                                    Precision   : 0.6753
# Recall      : 0.4298                                    Recall      : 0.6667
# F1 Score    : 0.4146                                    F1 Score    : 0.6625
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7778                                    FP Rate     : 0.4444
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 9
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1778                                    Loss        : 0.7038
# Accuracy    : 0.5119                                    Accuracy    : 0.5556
# Precision   : 0.5000                                    Precision   : 0.7647
# Recall      : 0.5000                                    Recall      : 0.5556
# F1 Score    : 0.4999                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 10
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.0041                                    Loss        : 0.7131
# Accuracy    : 0.6310                                    Accuracy    : 0.5000
# Precision   : 0.6048                                    Precision   : 0.2500
# Recall      : 0.5677                                    Recall      : 0.5000
# F1 Score    : 0.5534                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 11
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.2596                                    Loss        : 0.7207
# Accuracy    : 0.4762                                    Accuracy    : 0.5000
# Precision   : 0.2469                                    Precision   : 0.2500
# Recall      : 0.4651                                    Recall      : 0.5000
# F1 Score    : 0.3226                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 12
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.2891                                    Loss        : 0.7154
# Accuracy    : 0.4762                                    Accuracy    : 0.5000
# Precision   : 0.7349                                    Precision   : 0.2500
# Recall      : 0.5111                                    Recall      : 0.5000
# F1 Score    : 0.3414                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 13
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1708                                    Loss        : 0.7092
# Accuracy    : 0.5000                                    Accuracy    : 0.5000
# Precision   : 0.4026                                    Precision   : 0.2500
# Recall      : 0.4701                                    Recall      : 0.5000
# F1 Score    : 0.3713                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 14
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1017                                    Loss        : 0.7073
# Accuracy    : 0.5357                                    Accuracy    : 0.5556
# Precision   : 0.5348                                    Precision   : 0.7647
# Recall      : 0.5205                                    Recall      : 0.5556
# F1 Score    : 0.4729                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 15
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1295                                    Loss        : 0.7081
# Accuracy    : 0.5357                                    Accuracy    : 0.6111
# Precision   : 0.5232                                    Precision   : 0.6607
# Recall      : 0.5212                                    Recall      : 0.6111
# F1 Score    : 0.5159                                    F1 Score    : 0.5786
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8889                                    FP Rate     : 0.6667
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 16
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1527                                    Loss        : 0.7094
# Accuracy    : 0.5238                                    Accuracy    : 0.5000
# Precision   : 0.5278                                    Precision   : 0.2500
# Recall      : 0.5273                                    Recall      : 0.5000
# F1 Score    : 0.5227                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 17
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1729                                    Loss        : 0.7103
# Accuracy    : 0.4881                                    Accuracy    : 0.5000
# Precision   : 0.5031                                    Precision   : 0.2500
# Recall      : 0.5029                                    Recall      : 0.5000
# F1 Score    : 0.4822                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 18
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1666                                    Loss        : 0.7108
# Accuracy    : 0.4762                                    Accuracy    : 0.5000
# Precision   : 0.4510                                    Precision   : 0.2500
# Recall      : 0.4531                                    Recall      : 0.5000
# F1 Score    : 0.4510                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 19
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1199                                    Loss        : 0.7111
# Accuracy    : 0.5833                                    Accuracy    : 0.5000
# Precision   : 0.5719                                    Precision   : 0.2500
# Recall      : 0.5529                                    Recall      : 0.5000
# F1 Score    : 0.5353                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 20
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1721                                    Loss        : 0.7083
# Accuracy    : 0.4762                                    Accuracy    : 0.5000
# Precision   : 0.5498                                    Precision   : 0.2500
# Recall      : 0.5365                                    Recall      : 0.5000
# F1 Score    : 0.4612                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 21
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1653                                    Loss        : 0.7079
# Accuracy    : 0.5595                                    Accuracy    : 0.6111
# Precision   : 0.5661                                    Precision   : 0.6607
# Recall      : 0.5624                                    Recall      : 0.6111
# F1 Score    : 0.5544                                    F1 Score    : 0.5786
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8889                                    FP Rate     : 0.6667
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 22
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1087                                    Loss        : 0.7089
# Accuracy    : 0.5119                                    Accuracy    : 0.5000
# Precision   : 0.4131                                    Precision   : 0.2500
# Recall      : 0.4066                                    Recall      : 0.5000
# F1 Score    : 0.4094                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 23
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.0771                                    Loss        : 0.7201
# Accuracy    : 0.5833                                    Accuracy    : 0.5000
# Precision   : 0.7866                                    Precision   : 0.2500
# Recall      : 0.5270                                    Recall      : 0.5000
# F1 Score    : 0.4156                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 24
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.3204                                    Loss        : 0.7198
# Accuracy    : 0.4048                                    Accuracy    : 0.5000
# Precision   : 0.6988                                    Precision   : 0.2500
# Recall      : 0.5098                                    Recall      : 0.5000
# F1 Score    : 0.3037                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 25
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.0925                                    Loss        : 0.7161
# Accuracy    : 0.5833                                    Accuracy    : 0.5000
# Precision   : 0.2952                                    Precision   : 0.2500
# Recall      : 0.4900                                    Recall      : 0.5000
# F1 Score    : 0.3684                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 26
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.2043                                    Loss        : 0.7101
# Accuracy    : 0.4524                                    Accuracy    : 0.5000
# Precision   : 0.4756                                    Precision   : 0.2500
# Recall      : 0.4977                                    Recall      : 0.5000
# F1 Score    : 0.3292                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 27
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1265                                    Loss        : 0.7062
# Accuracy    : 0.4762                                    Accuracy    : 0.5556
# Precision   : 0.4857                                    Precision   : 0.7647
# Recall      : 0.4920                                    Recall      : 0.5556
# F1 Score    : 0.4207                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 28
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1412                                    Loss        : 0.7051
# Accuracy    : 0.5595                                    Accuracy    : 0.6111
# Precision   : 0.6111                                    Precision   : 0.6607
# Recall      : 0.5841                                    Recall      : 0.6111
# F1 Score    : 0.5407                                    F1 Score    : 0.5786
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8889                                    FP Rate     : 0.6667
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 29
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1674                                    Loss        : 0.7067
# Accuracy    : 0.4405                                    Accuracy    : 0.5000
# Precision   : 0.4428                                    Precision   : 0.2500
# Recall      : 0.4466                                    Recall      : 0.5000
# F1 Score    : 0.4340                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 30
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1603                                    Loss        : 0.7083
# Accuracy    : 0.4881                                    Accuracy    : 0.5000
# Precision   : 0.5031                                    Precision   : 0.2500
# Recall      : 0.5029                                    Recall      : 0.5000
# F1 Score    : 0.4822                                    F1 Score    : 0.3333
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.0000                                    FP Rate     : 0.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 31
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1713                                    Loss        : 0.7070
# Accuracy    : 0.4524                                    Accuracy    : 0.3889
# Precision   : 0.4581                                    Precision   : 0.3393
# Recall      : 0.4598                                    Recall      : 0.3889
# F1 Score    : 0.4496                                    F1 Score    : 0.3378
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.1111                                    FP Rate     : 0.3333
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 32
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1683                                    Loss        : 0.7062
# Accuracy    : 0.4643                                    Accuracy    : 0.6111
# Precision   : 0.4638                                    Precision   : 0.6607
# Recall      : 0.4643                                    Recall      : 0.6111
# F1 Score    : 0.4624                                    F1 Score    : 0.5786
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8889                                    FP Rate     : 0.6667
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 33
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1116                                    Loss        : 0.7061
# Accuracy    : 0.5714                                    Accuracy    : 0.5556
# Precision   : 0.5697                                    Precision   : 0.7647
# Recall      : 0.5659                                    Recall      : 0.5556
# F1 Score    : 0.5625                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 34
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.0985                                    Loss        : 0.7066
# Accuracy    : 0.5238                                    Accuracy    : 0.5556
# Precision   : 0.5167                                    Precision   : 0.7647
# Recall      : 0.5136                                    Recall      : 0.5556
# F1 Score    : 0.4952                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 35
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1190                                    Loss        : 0.7063
# ...
# Accuracy    : 0.5952                                    Accuracy    : 0.5556
# Precision   : 0.7927                                    Precision   : 0.7647
# Recall      : 0.5278                                    Recall      : 0.5556
# F1 Score    : 0.4219                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 290
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1335                                    Loss        : 0.6885
# Accuracy    : 0.4524                                    Accuracy    : 0.5556
# Precision   : 0.2262                                    Precision   : 0.7647
# Recall      : 0.5000                                    Recall      : 0.5556
# F1 Score    : 0.3115                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 291
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1086                                    Loss        : 0.6882
# Accuracy    : 0.4881                                    Accuracy    : 0.5556
# Precision   : 0.7410                                    Precision   : 0.7647
# Recall      : 0.5114                                    Recall      : 0.5556
# F1 Score    : 0.3474                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 292
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1309                                    Loss        : 0.6881
# Accuracy    : 0.4881                                    Accuracy    : 0.5556
# Precision   : 0.2440                                    Precision   : 0.7647
# Recall      : 0.5000                                    Recall      : 0.5556
# F1 Score    : 0.3280                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 293
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1042                                    Loss        : 0.6881
# Accuracy    : 0.5238                                    Accuracy    : 0.5556
# Precision   : 0.7590                                    Precision   : 0.7647
# Recall      : 0.5122                                    Recall      : 0.5556
# F1 Score    : 0.3651                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 294
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1218                                    Loss        : 0.6879
# Accuracy    : 0.5238                                    Accuracy    : 0.5556
# Precision   : 0.2619                                    Precision   : 0.7647
# Recall      : 0.5000                                    Recall      : 0.5556
# F1 Score    : 0.3438                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 295
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1285                                    Loss        : 0.6879
# Accuracy    : 0.5119                                    Accuracy    : 0.5556
# Precision   : 0.2560                                    Precision   : 0.7647
# Recall      : 0.5000                                    Recall      : 0.5556
# F1 Score    : 0.3386                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 296
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1387                                    Loss        : 0.6881
# Accuracy    : 0.4762                                    Accuracy    : 0.5556
# Precision   : 0.2381                                    Precision   : 0.7647
# Recall      : 0.5000                                    Recall      : 0.5556
# F1 Score    : 0.3226                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 297
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.0907                                    Loss        : 0.6881
# Accuracy    : 0.5000                                    Accuracy    : 0.5556
# Precision   : 0.7439                                    Precision   : 0.7647
# Recall      : 0.5227                                    Recall      : 0.5556
# F1 Score    : 0.3713                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 298
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1031                                    Loss        : 0.6880
# Accuracy    : 0.4524                                    Accuracy    : 0.5556
# Precision   : 0.7229                                    Precision   : 0.7647
# Recall      : 0.5106                                    Recall      : 0.5556
# F1 Score    : 0.3292                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 299
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.1056                                    Loss        : 0.6879
# Accuracy    : 0.5238                                    Accuracy    : 0.5556
# Precision   : 0.7590                                    Precision   : 0.7647
# Recall      : 0.5122                                    Recall      : 0.5556
# F1 Score    : 0.3651                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 300
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 2.0948                                    Loss        : 0.6879
# Accuracy    : 0.4286                                    Accuracy    : 0.5556
# Precision   : 0.7073                                    Precision   : 0.7647
# Recall      : 0.5200                                    Recall      : 0.5556
# F1 Score    : 0.3316                                    F1 Score    : 0.4462
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 0.8889
# ====================================================================================================

# %% [markdown]
# ## Ewaluacja modelu

# %%
from utils.model_functions import eval_torch_model_binary

eval_torch_model_binary(model, criterion, X_test, y_test)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                                              VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.7067
# Accuracy    : 0.5789
# Precision   : 0.2895
# Recall      : 0.5000
# F1 Score    : 0.3667
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================

# %% [markdown]
# # MODEL SEGLEARN

# %%
from xgboost import XGBClassifier
from seglearn.pipe import Pype
from seglearn.transform import FeatureRep, Segment

# %% [markdown]
# ### Przekształcenie danych na wektor płaski połączonych współrzędnych

# %%
X_train_np = X_train.numpy()
X_val_np = X_val.numpy()
X_test_np = X_test.numpy()
y_train_np = y_train.numpy()
y_val_np = y_val.numpy()
y_test_np = y_test.numpy()

# %%
def flatten_landmarks(data):
    n_samples, n_timesteps, n_landmarks, n_coords = data.shape
    return data.reshape(n_samples, n_timesteps, n_landmarks * n_coords)

X_train_flat = flatten_landmarks(X_train_np)
X_val_flat = flatten_landmarks(X_val_np)
X_test_flat = flatten_landmarks(X_test_np)

# %%
print(X_train_flat.shape, y_train_np.shape)
# Out:
# (224, 1679, 956) (224,)

# %% [markdown]
# ### Budowa modelu

# %%
pipe = Pype([
    ("segment", Segment(width=20, step=10)),  # Segmentacja sekwencji
    ("features", FeatureRep()),              # Ekstrakcja cech
    ("xgb", XGBClassifier(
        eval_metric='logloss',
        n_estimators=200
    ))
])

# %% [markdown]
# ### Trening modelu

# %%
pipe.fit(X_train_flat, y_train_np)
# Out:
# Pype(steps=[('segment', Segment(overlap=None, step=10, width=20)),
#             ('features',
#              FeatureRep(features={'abs_energy': <function abs_energy at 0x0000023A8F32AB60>,
#                                   'kurt': <function kurt at 0x0000023A8F32B060>,
#                                   'max': <function maximum at 0x0000023A8F32AF20>,
#                                   'mean': <function mean at 0x0000023A8F32A7A0>,
#                                   'median': <function median at 0x0000023A8F32A840>,
#                                   'min': <function minimum at 0x...
#                            gamma=None, grow_policy=None, importance_type=None,
#                            interaction_constraints=None, learning_rate=None,
#                            max_bin=None, max_cat_threshold=None,
#                            max_cat_to_onehot=None, max_delta_step=None,
#                            max_depth=None, max_leaves=None,
#                            min_child_weight=None, missing=nan,
#                            monotone_constraints=None, multi_strategy=None,
#                            n_estimators=200, n_jobs=None,
#                            num_parallel_tree=None, random_state=None, ...))])

# %% [markdown]
# ### Ewaluacja modelu

# %%
val_accuracy = pipe.score(X_val_flat, y_val_np)
test_accuracy = pipe.score(X_test_flat, y_test_np)

print(f"Dokładność na zbiorze walidacyjnym: {val_accuracy:.2f}")
print(f"Dokładność na zbiorze testowym: {test_accuracy:.2f}")
# Out:
# Dokładność na zbiorze walidacyjnym: 0.36
# Dokładność na zbiorze testowym: 0.40

# %% [markdown]
# # TODYNET

# %% [markdown]
# ### Przygotowanie danych

# %%
TodyNet_DATA_PATH = os.path.join("..", "..", "src", "external", "TodyNet", "data", "UCR", "SILESIAN_DECEPTION")

os.makedirs(TodyNet_DATA_PATH, exist_ok=True)

# %%
X_train_tensor = torch.tensor(X_train_flat, dtype=torch.float32).unsqueeze(1)  # adding channel dimension
X_val_tensor = torch.tensor(X_val_flat, dtype=torch.float32).unsqueeze(1)
X_test_tensor = torch.tensor(X_test_flat, dtype=torch.float32).unsqueeze(1)

# Save the data in PyTorch (.pt) format
torch.save(X_train_tensor, os.path.join(TodyNet_DATA_PATH, 'X_train.pt'))
torch.save(X_val_tensor, os.path.join(TodyNet_DATA_PATH, 'X_valid.pt'))
torch.save(X_test_tensor, os.path.join(TodyNet_DATA_PATH, 'X.pt'))

# Save the labels in PyTorch (.pt) format
torch.save(y_train, os.path.join(TodyNet_DATA_PATH, 'y_train.pt'))
torch.save(y_val, os.path.join(TodyNet_DATA_PATH, 'y_valid.pt'))
torch.save(y_test, os.path.join(TodyNet_DATA_PATH, 'y.pt'))

# %%
X_train_tensor.shape
# Out:
# torch.Size([224, 1, 1679, 956])

# %% [markdown]
# ### Trening modelu [pool_ratio 0.8, ponieważ rozmiar danych jest zbyt duży na 0.2]

# %%
# cd .\src\external\TodyNet\src\ & python train.py --dataset='SILESIAN_DECEPTION' --pool_ratio 0.8
