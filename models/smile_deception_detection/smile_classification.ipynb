# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
from utils import get_cuda_info

get_cuda_info()
# Out:
# PyTorch version: 2.5.1+cu118
# **********
# _CUDA version:
# CUDA version:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Wed_Oct_30_01:18:48_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.85
# Build cuda_12.6.r12.6/compiler.35059454_0
#
# **********
# CUDNN version: 90100
# Available GPU devices: 1
# Device Name: NVIDIA GeForce RTX 4070 Ti SUPER

# %% [markdown]
# ## Zdobycie danych

# %%
from utils import load_data

all_data, all_labels = load_data('nemo_smile')

# %% [markdown]
# ## Preprocessing danych

# %%
from utils import preprocess_data

X_train, X_val, X_test, y_train, y_val, y_test = preprocess_data(all_data, all_labels, binarize_labels=False)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([868, 609, 478, 2])
# torch.Size([868])

# %%
from utils import get_class_distribution

get_class_distribution(all_labels)
# Out:
# ===> Class distribution <===
# 0: 597
# 1: 643
# =============><=============

# %% [markdown]
# # MODEL TORCH

# %% [markdown]
# ### W podejściu wykorzystane zostaną 2 modele - pierwszy z nich będzie siecią konwolucyjną 2d, która będzie miała za zadanie nauczyć się rozpoznawać cechy charakterystyczne dla wybranej klatki (zbioru współrzędnych pkt charakterystycznych). Do klasyfikacji szeregu czasowego zostanie wykorzystana sekwencyjna sieć neuronowa LSTM.

# %% [markdown]
# ## Zbudowanie modelu ekstrakcji cech

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class SmileClassifier(nn.Module):
    def __init__(self):
        super(SmileClassifier, self).__init__()
        
        # Spatial feature extraction
        self.conv1 = nn.Conv1d(in_channels=2, out_channels=32, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2)
        
        # Calculate the correct dimension after convolutions
        # Assuming initial landmarks is 478 (since 239*2=478)
        # After pool1: 239, after pool2: 119
        self.conv_output_size = 64 * 119  # 64 channels * 119 landmarks
        
        # Temporal feature extraction
        self.lstm = nn.LSTM(input_size=self.conv_output_size, hidden_size=128, 
                           batch_first=True, bidirectional=True)
        
        # Classification head
        self.attn = nn.Linear(256, 1)
        self.fc1 = nn.Linear(256, 64)  # 128*2 for bidirectional
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(64, 1)
        
        # Initialize weights
        self._init_weights()

    def _init_weights(self):
        for name, param in self.named_parameters():
            if 'weight' in name:
                nn.init.xavier_normal_(param)
            elif 'bias' in name:
                nn.init.constant_(param, 0.1)

    def forward(self, x):
        # x shape: (batch_size, frames, landmarks, coordinates)
        batch_size, frames, landmarks, coordinates = x.shape
        
        # Reshape for Conv1D: combine batch and frames
        x = x.view(-1, landmarks, coordinates)  # (batch*frames, landmarks, 2)
        x = x.permute(0, 2, 1)  # (batch*frames, 2, landmarks)
        
        # Spatial features
        x = F.relu(self.conv1(x))
        x = self.pool1(x)  # (batch*frames, 32, landmarks//2)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)  # (batch*frames, 64, landmarks//4)
        
        # Flatten spatial features
        x = x.view(batch_size, frames, -1)  # (batch, frames, 64*(landmarks//4))
        
        # Temporal features with attention
        x, _ = self.lstm(x)
        attn_weights = torch.softmax(self.attn(x), dim=1)
        x = (x * attn_weights).sum(dim=1)
        
        # Classification head (remove sigmoid!)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        return self.fc2(x)  # Raw logits

# %%
from torch.optim import Adam

model = SmileClassifier()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pos_weight = torch.tensor([(len(y_train) - y_train.sum()) / y_train.sum()]).to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# ## Trening modelu

# %%
from torch.utils.tensorboard import SummaryWriter

RUNS_FOLDER_PATH = os.path.abspath('runs')
writer_path = os.path.join('runs', 'torch_lstm', 'fake_smile_classifier')
writer = SummaryWriter(writer_path)

# %%
from utils.model_functions import train_torch_model_binary

train_torch_model_binary(model, criterion, optimizer, X_train, y_train, X_val, y_val, writer=writer, batch_size=32, unbalanced=True, show_prediction_stats=False)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 17.130543                                    Loss        : 3.422076
# Accuracy    : 0.5876                                    Accuracy    : 0.5645
# Precision   : 0.5896                                    Precision   : 0.6114
# Recall      : 0.5876                                    Recall      : 0.5570
# F1 Score    : 0.5852                                    F1 Score    : 0.4996
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2088                                    FP Rate     : 0.0947
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 2
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 15.728518                                    Loss        : 3.197722
# Accuracy    : 0.6601                                    Accuracy    : 0.7258
# Precision   : 0.6605                                    Precision   : 0.7379
# Recall      : 0.6593                                    Recall      : 0.7281
# F1 Score    : 0.6591                                    F1 Score    : 0.7235
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8352                                    FP Rate     : 0.3789
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 3
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.539679                                    Loss        : 3.113050
# Accuracy    : 0.7316                                    Accuracy    : 0.7312
# Precision   : 0.7315                                    Precision   : 0.7365
# Recall      : 0.7247                                    Recall      : 0.7327
# F1 Score    : 0.7261                                    F1 Score    : 0.7304
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8022                                    FP Rate     : 0.3368
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 4
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.063474                                    Loss        : 3.090519
# Accuracy    : 0.7604                                    Accuracy    : 0.7151
# Precision   : 0.7613                                    Precision   : 0.7156
# Recall      : 0.7602                                    Recall      : 0.7155
# F1 Score    : 0.7601                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 5
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.194587                                    Loss        : 3.083870
# Accuracy    : 0.7270                                    Accuracy    : 0.7312
# Precision   : 0.7270                                    Precision   : 0.7351
# Recall      : 0.7235                                    Recall      : 0.7324
# F1 Score    : 0.7242                                    F1 Score    : 0.7307
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7912                                    FP Rate     : 0.3263
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 6
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.181966                                    Loss        : 3.105139
# Accuracy    : 0.7327                                    Accuracy    : 0.7151
# Precision   : 0.7333                                    Precision   : 0.7156
# Recall      : 0.7328                                    Recall      : 0.7155
# F1 Score    : 0.7326                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 7
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.246519                                    Loss        : 3.121725
# Accuracy    : 0.7558                                    Accuracy    : 0.7151
# Precision   : 0.7595                                    Precision   : 0.7319
# Recall      : 0.7555                                    Recall      : 0.7178
# F1 Score    : 0.7547                                    F1 Score    : 0.7114
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8462                                    FP Rate     : 0.4105
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 8
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.376384                                    Loss        : 3.076192
# Accuracy    : 0.7523                                    Accuracy    : 0.7151
# Precision   : 0.7571                                    Precision   : 0.7156
# Recall      : 0.7492                                    Recall      : 0.7155
# F1 Score    : 0.7493                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 9
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.773286                                    Loss        : 3.056116
# Accuracy    : 0.7327                                    Accuracy    : 0.7312
# Precision   : 0.7347                                    Precision   : 0.7351
# Recall      : 0.7323                                    Recall      : 0.7324
# F1 Score    : 0.7319                                    F1 Score    : 0.7307
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7912                                    FP Rate     : 0.3263
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 10
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.103368                                    Loss        : 3.068062
# Accuracy    : 0.7350                                    Accuracy    : 0.7258
# Precision   : 0.7428                                    Precision   : 0.7379
# Recall      : 0.7346                                    Recall      : 0.7281
# F1 Score    : 0.7326                                    F1 Score    : 0.7235
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8352                                    FP Rate     : 0.3789
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 11
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.279477                                    Loss        : 3.107995
# Accuracy    : 0.7362                                    Accuracy    : 0.6989
# Precision   : 0.7455                                    Precision   : 0.6988
# Recall      : 0.7216                                    Recall      : 0.6988
# F1 Score    : 0.7233                                    F1 Score    : 0.6988
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.6923                                    FP Rate     : 0.2947
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 12
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.226694                                    Loss        : 3.257351
# Accuracy    : 0.7247                                    Accuracy    : 0.6989
# Precision   : 0.7245                                    Precision   : 0.7560
# Recall      : 0.7245                                    Recall      : 0.7039
# F1 Score    : 0.7245                                    F1 Score    : 0.6843
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.9341                                    FP Rate     : 0.5263
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 13
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.689190                                    Loss        : 3.260167
# Accuracy    : 0.7293                                    Accuracy    : 0.6989
# Precision   : 0.7362                                    Precision   : 0.7628
# Recall      : 0.7280                                    Recall      : 0.7041
# F1 Score    : 0.7265                                    F1 Score    : 0.6827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.9451                                    FP Rate     : 0.5368
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 14
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.656807                                    Loss        : 3.058750
# Accuracy    : 0.7661                                    Accuracy    : 0.7312
# Precision   : 0.7712                                    Precision   : 0.7365
# Recall      : 0.7650                                    Recall      : 0.7327
# F1 Score    : 0.7645                                    F1 Score    : 0.7304
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8022                                    FP Rate     : 0.3368
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 15
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.177497                                    Loss        : 3.210136
# Accuracy    : 0.7270                                    Accuracy    : 0.6398
# Precision   : 0.7255                                    Precision   : 0.6447
# Recall      : 0.7271                                    Recall      : 0.6374
# F1 Score    : 0.7258                                    F1 Score    : 0.6342
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.5275                                    FP Rate     : 0.2526
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 16
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.491067                                    Loss        : 3.079552
# Accuracy    : 0.7362                                    Accuracy    : 0.7151
# Precision   : 0.7394                                    Precision   : 0.7156
# Recall      : 0.7356                                    Recall      : 0.7155
# F1 Score    : 0.7350                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 17
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.459389                                    Loss        : 3.047709
# Accuracy    : 0.7512                                    Accuracy    : 0.7312
# Precision   : 0.7589                                    Precision   : 0.7351
# Recall      : 0.7430                                    Recall      : 0.7324
# F1 Score    : 0.7441                                    F1 Score    : 0.7307
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7912                                    FP Rate     : 0.3263
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 18
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.715398                                    Loss        : 3.142743
# Accuracy    : 0.7604                                    Accuracy    : 0.6720
# Precision   : 0.7644                                    Precision   : 0.6722
# Recall      : 0.7607                                    Recall      : 0.6713
# F1 Score    : 0.7596                                    F1 Score    : 0.6713
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.6374                                    FP Rate     : 0.2947
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 19
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.469587                                    Loss        : 3.087923
# Accuracy    : 0.7581                                    Accuracy    : 0.7151
# Precision   : 0.7594                                    Precision   : 0.7419
# Recall      : 0.7594                                    Recall      : 0.7185
# F1 Score    : 0.7581                                    F1 Score    : 0.7089
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8791                                    FP Rate     : 0.4421
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 20
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.539728                                    Loss        : 3.196106
# Accuracy    : 0.7673                                    Accuracy    : 0.6613
# Precision   : 0.7715                                    Precision   : 0.6630
# Recall      : 0.7668                                    Recall      : 0.6599
# F1 Score    : 0.7662                                    F1 Score    : 0.6591
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.5934                                    FP Rate     : 0.2737
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 21
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.992071                                    Loss        : 3.062960
# Accuracy    : 0.7454                                    Accuracy    : 0.7151
# Precision   : 0.7493                                    Precision   : 0.7156
# Recall      : 0.7463                                    Recall      : 0.7155
# F1 Score    : 0.7448                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 22
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.111327                                    Loss        : 3.037754
# Accuracy    : 0.7385                                    Accuracy    : 0.7312
# Precision   : 0.7411                                    Precision   : 0.7423
# Recall      : 0.7405                                    Recall      : 0.7334
# F1 Score    : 0.7385                                    F1 Score    : 0.7292
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8352                                    FP Rate     : 0.3684
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 23
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.799589                                    Loss        : 3.039701
# Accuracy    : 0.7638                                    Accuracy    : 0.7312
# Precision   : 0.7659                                    Precision   : 0.7365
# Recall      : 0.7613                                    Recall      : 0.7327
# F1 Score    : 0.7619                                    F1 Score    : 0.7304
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8022                                    FP Rate     : 0.3368
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 24
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.494029                                    Loss        : 3.080774
# Accuracy    : 0.7442                                    Accuracy    : 0.7204
# Precision   : 0.7468                                    Precision   : 0.7460
# Recall      : 0.7471                                    Recall      : 0.7238
# F1 Score    : 0.7442                                    F1 Score    : 0.7149
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8791                                    FP Rate     : 0.4316
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 25
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.153138                                    Loss        : 3.150527
# Accuracy    : 0.7558                                    Accuracy    : 0.7258
# Precision   : 0.7622                                    Precision   : 0.7678
# Recall      : 0.7563                                    Recall      : 0.7300
# F1 Score    : 0.7545                                    F1 Score    : 0.7169
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.9231                                    FP Rate     : 0.4632
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 26
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.234570                                    Loss        : 3.041338
# Accuracy    : 0.7753                                    Accuracy    : 0.7312
# Precision   : 0.7811                                    Precision   : 0.7401
# Recall      : 0.7784                                    Recall      : 0.7331
# F1 Score    : 0.7751                                    F1 Score    : 0.7297
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8242                                    FP Rate     : 0.3579
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 27
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.813212                                    Loss        : 3.050205
# Accuracy    : 0.7258                                    Accuracy    : 0.7151
# Precision   : 0.7374                                    Precision   : 0.7156
# Recall      : 0.7216                                    Recall      : 0.7155
# F1 Score    : 0.7197                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 28
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 12.997444                                    Loss        : 3.036495
# Accuracy    : 0.7673                                    Accuracy    : 0.7312
# Precision   : 0.7687                                    Precision   : 0.7365
# Recall      : 0.7674                                    Recall      : 0.7327
# F1 Score    : 0.7670                                    F1 Score    : 0.7304
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8022                                    FP Rate     : 0.3368
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 29
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.134035                                    Loss        : 3.082372
# Accuracy    : 0.7316                                    Accuracy    : 0.7204
# Precision   : 0.7338                                    Precision   : 0.7499
# Recall      : 0.7327                                    Recall      : 0.7240
# F1 Score    : 0.7314                                    F1 Score    : 0.7139
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8901                                    FP Rate     : 0.4421
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 30
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.556726                                    Loss        : 3.031329
# Accuracy    : 0.7270                                    Accuracy    : 0.7312
# Precision   : 0.7337                                    Precision   : 0.7401
# Recall      : 0.7253                                    Recall      : 0.7331
# F1 Score    : 0.7239                                    F1 Score    : 0.7297
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8242                                    FP Rate     : 0.3579
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 31
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.093388                                    Loss        : 3.051896
# Accuracy    : 0.7546                                    Accuracy    : 0.7151
# Precision   : 0.7626                                    Precision   : 0.7156
# Recall      : 0.7565                                    Recall      : 0.7155
# F1 Score    : 0.7535                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 32
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 12.882681                                    Loss        : 3.071244
# Accuracy    : 0.7892                                    Accuracy    : 0.7151
# Precision   : 0.7907                                    Precision   : 0.7156
# Recall      : 0.7883                                    Recall      : 0.7155
# F1 Score    : 0.7885                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 33
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.690035                                    Loss        : 3.040903
# Accuracy    : 0.7235                                    Accuracy    : 0.7312
# Precision   : 0.7268                                    Precision   : 0.7423
# Recall      : 0.7240                                    Recall      : 0.7334
# F1 Score    : 0.7228                                    F1 Score    : 0.7292
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8352                                    FP Rate     : 0.3684
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 34
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.275820                                    Loss        : 3.060832
# Accuracy    : 0.7373                                    Accuracy    : 0.7151
# Precision   : 0.7400                                    Precision   : 0.7156
# Recall      : 0.7358                                    Recall      : 0.7155
# F1 Score    : 0.7356                                    F1 Score    : 0.7150
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7363                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 35
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ...
# Precision   : 0.8011                                    Precision   : 0.7264
# Recall      : 0.7984                                    Recall      : 0.7263
# F1 Score    : 0.7979                                    F1 Score    : 0.7258
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7473                                    FP Rate     : 0.2947
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 290
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.121809                                    Loss        : 3.034777
# Accuracy    : 0.7615                                    Accuracy    : 0.7097
# Precision   : 0.7631                                    Precision   : 0.7097
# Recall      : 0.7636                                    Recall      : 0.7098
# F1 Score    : 0.7615                                    F1 Score    : 0.7096
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7143                                    FP Rate     : 0.2947
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 291
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 12.751507                                    Loss        : 3.036968
# Accuracy    : 0.8007                                    Accuracy    : 0.7097
# Precision   : 0.8014                                    Precision   : 0.7097
# Recall      : 0.8018                                    Recall      : 0.7098
# F1 Score    : 0.8007                                    F1 Score    : 0.7096
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7143                                    FP Rate     : 0.2947
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 292
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.217147                                    Loss        : 3.035619
# Accuracy    : 0.7546                                    Accuracy    : 0.7097
# Precision   : 0.7590                                    Precision   : 0.7097
# Recall      : 0.7552                                    Recall      : 0.7098
# F1 Score    : 0.7538                                    F1 Score    : 0.7096
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7143                                    FP Rate     : 0.2947
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 293
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.459332                                    Loss        : 2.966798
# Accuracy    : 0.7615                                    Accuracy    : 0.7312
# Precision   : 0.7629                                    Precision   : 0.7365
# Recall      : 0.7616                                    Recall      : 0.7327
# F1 Score    : 0.7613                                    F1 Score    : 0.7304
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8022                                    FP Rate     : 0.3368
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 294
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 14.096673                                    Loss        : 2.975533
# Accuracy    : 0.7523                                    Accuracy    : 0.7312
# Precision   : 0.7592                                    Precision   : 0.7338
# Recall      : 0.7530                                    Recall      : 0.7322
# F1 Score    : 0.7510                                    F1 Score    : 0.7309
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7802                                    FP Rate     : 0.3158
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 295
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 12.802496                                    Loss        : 2.987530
# Accuracy    : 0.7719                                    Accuracy    : 0.7366
# Precision   : 0.7744                                    Precision   : 0.7581
# Recall      : 0.7705                                    Recall      : 0.7396
# F1 Score    : 0.7706                                    F1 Score    : 0.7325
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8791                                    FP Rate     : 0.4000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 296
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.533629                                    Loss        : 2.966495
# Accuracy    : 0.7592                                    Accuracy    : 0.7312
# Precision   : 0.7629                                    Precision   : 0.7351
# Recall      : 0.7566                                    Recall      : 0.7324
# F1 Score    : 0.7569                                    F1 Score    : 0.7307
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7912                                    FP Rate     : 0.3263
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 297
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 12.462142                                    Loss        : 2.961782
# Accuracy    : 0.7961                                    Accuracy    : 0.7312
# Precision   : 0.7998                                    Precision   : 0.7365
# Recall      : 0.7916                                    Recall      : 0.7327
# F1 Score    : 0.7931                                    F1 Score    : 0.7304
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8022                                    FP Rate     : 0.3368
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 298
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 12.998432                                    Loss        : 2.962707
# Accuracy    : 0.7776                                    Accuracy    : 0.7258
# Precision   : 0.7797                                    Precision   : 0.7379
# Recall      : 0.7770                                    Recall      : 0.7281
# F1 Score    : 0.7769                                    F1 Score    : 0.7235
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8352                                    FP Rate     : 0.3789
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 299
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 12.288170                                    Loss        : 2.979707
# Accuracy    : 0.8030                                    Accuracy    : 0.7312
# Precision   : 0.8037                                    Precision   : 0.7328
# Recall      : 0.8023                                    Recall      : 0.7320
# F1 Score    : 0.8025                                    F1 Score    : 0.7311
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7692                                    FP Rate     : 0.3053
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 300
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 13.864394                                    Loss        : 2.982441
# Accuracy    : 0.7592                                    Accuracy    : 0.7366
# Precision   : 0.7594                                    Precision   : 0.7548
# Recall      : 0.7599                                    Recall      : 0.7393
# F1 Score    : 0.7591                                    F1 Score    : 0.7332
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.8681                                    FP Rate     : 0.3895
# ====================================================================================================

# %% [markdown]
# ## Ewaluacja modelu

# %%
from utils.model_functions import eval_torch_model_binary

eval_torch_model_binary(model, criterion, X_test, y_test)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                                              VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 3.415825
# Accuracy    : 0.6828
# Precision   : 0.6912
# Recall      : 0.6874
# F1 Score    : 0.6821
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.7727                                    FP Rate     : 0.3980
# ====================================================================================================

# %% [markdown]
# # TODYNET

# %% [markdown]
# ### Przygotowanie danych

# %%
X_train_np = X_train.numpy()
X_val_np = X_val.numpy()
X_test_np = X_test.numpy()
y_train_np = y_train.numpy()
y_val_np = y_val.numpy()
y_test_np = y_test.numpy()

# %%
def flatten_landmarks(data):
    n_samples, n_timesteps, n_landmarks, n_coords = data.shape
    return data.reshape(n_samples, n_timesteps, n_landmarks * n_coords)

X_train_flat = flatten_landmarks(X_train_np)
X_val_flat = flatten_landmarks(X_val_np)
X_test_flat = flatten_landmarks(X_test_np)

# %%
X_train_flat.shape
# Out:
# (868, 609, 956)

# %%
TodyNet_DATA_PATH = os.path.join("..", "..", "src", "external", "TodyNet", "data", "UCR", "NEMO_SMILE")

os.makedirs(TodyNet_DATA_PATH, exist_ok=True)

# %%
import torch

X_train_tensor = torch.tensor(X_train_flat, dtype=torch.float32).unsqueeze(1)  # adding channel dimension
X_val_tensor = torch.tensor(X_val_flat, dtype=torch.float32).unsqueeze(1)
X_test_tensor = torch.tensor(X_test_flat, dtype=torch.float32).unsqueeze(1)

# Save the data in PyTorch (.pt) format
torch.save(X_train_tensor, os.path.join(TodyNet_DATA_PATH, 'X_train.pt'))
torch.save(X_val_tensor, os.path.join(TodyNet_DATA_PATH, 'X_valid.pt'))
torch.save(X_test_tensor, os.path.join(TodyNet_DATA_PATH, 'X.pt'))

# Save the labels in PyTorch (.pt) format
torch.save(y_train.long(), os.path.join(TodyNet_DATA_PATH, 'y_train.pt'))
torch.save(y_val.long(), os.path.join(TodyNet_DATA_PATH, 'y_valid.pt'))
torch.save(y_test.long(), os.path.join(TodyNet_DATA_PATH, 'y.pt'))

# %%
X_train_tensor.shape
# Out:
# torch.Size([868, 1, 609, 956])

# %% [markdown]
# ### Trening modelu Zmiejszone parametry ze względu na wielkość modelu

# %%
# cd .\src\external\TodyNet\src\ & python train.py --dataset='NEMO_SMILE' --num_layers 1 --in_dim 16 --hidden_dim 16 --out_dim 16 --pool_ratio 0.0 --kern_size "3" --groups 1

# %% [markdown]
# ## Najlepszy wynik
#
# TRAIN, epoch 16, loss 0.5146783623277866, acc tensor([75.4608], device='cuda:0')
#
# VAL, loss 0.5493738343638759, acc tensor([73.1183], device='cuda:0')
