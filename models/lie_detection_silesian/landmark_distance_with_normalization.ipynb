# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
from utils import get_cuda_info

get_cuda_info()
# Out:
# PyTorch version: 2.5.1+cu118
# **********
# _CUDA version:
# CUDA version:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Wed_Oct_30_01:18:48_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.85
# Build cuda_12.6.r12.6/compiler.35059454_0
#
# **********
# CUDNN version: 90100
# Available GPU devices: 1
# Device Name: NVIDIA GeForce RTX 4070 Ti SUPER

# %% [markdown]
# ## Wybór optymalnych punktów charakterystycznych

# %%
import numpy as np

LANDMARK_INDEXES = np.load(os.path.join('..', '..', 'data', 'landmarks', 'combined_selected_points_emotions.npy'))
REFERENCE_POINT_IDX = 0

# %% [markdown]
# ### Wizualizacja wybranych punktów

# %%
from utils import visualize_landmarks

visualize_landmarks(LANDMARK_INDEXES)

# %% [markdown]
# ### Zdobycie danych

# %%
from utils import load_data, convert_landmarks_to_distances

all_data, all_labels = load_data('silesian_deception')
all_data = convert_landmarks_to_distances(all_data, LANDMARK_INDEXES, REFERENCE_POINT_IDX, normalize=True)

# %% [markdown]
# ## Preprocessing danych

# %%
from utils import preprocess_data

X_train, X_val, X_test, y_train, y_val, y_test = preprocess_data(all_data, all_labels, binarize_labels=False)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([700, 4045, 154])
# torch.Size([700])

# %% [markdown]
# # MODEL TORCH

# %% [markdown]
# ## Zbudowanie modelu ekstrakcji cech

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class LieClassifier(nn.Module):
    def __init__(self, input_distances):
        super(LieClassifier, self).__init__()
        
        # Spatial feature extraction (changed in_channels to 1)
        self.conv1 = nn.Conv1d(in_channels=1, out_channels=32, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2)
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool1d(kernel_size=2)
        
        # Calculate LSTM input dimension
        self.conv_output_size = 64 * (input_distances // 4)  # After two poolings
        
        # Temporal feature extraction
        self.lstm = nn.LSTM(input_size=self.conv_output_size, hidden_size=128,
                          batch_first=True, bidirectional=True)
        
        # Classification head
        self.attn = nn.Linear(256, 1)
        self.fc1 = nn.Linear(256, 64)  # 128*2 for bidirectional
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(64, 1)
        
        self._init_weights()

    def _init_weights(self):
        for name, param in self.named_parameters():
            if 'weight' in name:
                nn.init.xavier_normal_(param)
            elif 'bias' in name:
                nn.init.constant_(param, 0.1)

    def forward(self, x):
        # x shape: (batch_size, frames, distances)
        batch_size, frames, distances = x.shape
        
        # Reshape for Conv1D: (batch*frames, 1, distances)
        x = x.view(-1, 1, distances)
        
        # Spatial features
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        
        # Prepare for LSTM
        x = x.view(batch_size, frames, -1)
        
        # Temporal features
        x, _ = self.lstm(x)
        attn_weights = torch.softmax(self.attn(x), dim=1)
        x = (x * attn_weights).sum(dim=1)
        
        # Classification head (remove sigmoid!)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        return self.fc2(x)  # Raw logits

# %%
from torch.optim import Adam

model = LieClassifier(input_distances=len(LANDMARK_INDEXES))
pos_weight = torch.tensor([2.0]).to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# ### Diagnostyka

# %%
from utils.model_functions import overfit_model

model_diag = LieClassifier(input_distances=len(LANDMARK_INDEXES))
pos_weight_diag = torch.tensor([2.0]).to(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
criterion_diag = nn.BCEWithLogitsLoss(pos_weight=pos_weight_diag)
optimizer_diag = Adam(model.parameters(), lr=1e-3)

overfit_model(model_diag, criterion_diag, optimizer_diag, X_train, y_train, prediction_threshold=0.5)
# Out:
# === Debug Mode ===
# Input shape: torch.Size([32, 4045, 154])
# Label distribution: 0.81 (1s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 8
#       5 criterion_diag = nn.BCEWithLogitsLoss(pos_weight=pos_weight_diag)
#       6 optimizer_diag = Adam(model.parameters(), lr=1e-3)
# ----> 8 overfit_model(model_diag, criterion_diag, optimizer_diag, X_train, y_train, prediction_treshold=0.5)
#
# File c:\Users\Bartosz\Desktop\automatic-lie-detection\models\utils\model_functions\train_model.py:187, in overfit_model(model, criterion, optimizer, X_train, y_train, batch_size, prediction_treshold)
#     185 for step in range(1000):
#     186     optimizer.zero_grad()
# --> 187     outputs = model(X_debug).squeeze(1)
#     189     # Convert outputs to probabilities and predictions
#     190     probs = torch.sigmoid(outputs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[9], line 50, in LieClassifier.forward(self, x)
#      47 x = x.view(batch_size, frames, -1)
#      49 # Temporal features
# ---> 50 x, _ = self.lstm(x)
#      51 attn_weights = torch.softmax(self.attn(x), dim=1)
#      52 x = (x * attn_weights).sum(dim=1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torch\nn\modules\rnn.py:1123, in LSTM.forward(self, input, hx)
#    1120         hx = self.permute_hidden(hx, sorted_indices)
#    1122 if batch_sizes is None:
# -> 1123     result = _VF.lstm(
#    1124         input,
#    1125         hx,
#    1126         self._flat_weights,
#    1127         self.bias,
#    1128         self.num_layers,
#    1129         self.dropout,
#    1130         self.training,
#    1131         self.bidirectional,
#    1132         self.batch_first,
#    1133     )
#    1134 else:
#    1135     result = _VF.lstm(
#    1136         input,
#    1137         batch_sizes,
#    (...)
#    1144         self.bidirectional,
#    1145     )
#
# KeyboardInterrupt:

# %% [markdown]
# ## Trening modelu

# %%
from torch.utils.tensorboard import SummaryWriter

RUNS_FOLDER_PATH = os.path.abspath('runs')
writer_path = os.path.join('runs', 'torch_lstm', 'lie_classifier_landmark_distance_normalized')
writer = SummaryWriter(writer_path)

# %%
from utils.model_functions import train_torch_model_binary

train_torch_model_binary(model, criterion, optimizer, X_train, y_train, X_val, y_val, unbalanced=True, writer=writer, prediction_threshold=0.5, epochs=50)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.8535                                    Loss        : 4.7787
# Accuracy    : 0.4786                                    Accuracy    : 0.6867
# Precision   : 0.4647                                    Precision   : 0.3433
# Recall      : 0.4961                                    Recall      : 0.5000
# F1 Score    : 0.3440                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 2
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.3761                                    Loss        : 4.7705
# Accuracy    : 0.4957                                    Accuracy    : 0.6867
# Precision   : 0.2479                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3314                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 3
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1677                                    Loss        : 4.4293
# Accuracy    : 0.5229                                    Accuracy    : 0.6867
# Precision   : 0.2614                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3433                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 4
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1770                                    Loss        : 4.6876
# Accuracy    : 0.4914                                    Accuracy    : 0.6867
# Precision   : 0.2457                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3295                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 5
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.3972                                    Loss        : 4.6889
# Accuracy    : 0.4914                                    Accuracy    : 0.6867
# Precision   : 0.2457                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3295                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 6
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.2025                                    Loss        : 4.7562
# Accuracy    : 0.4900                                    Accuracy    : 0.6867
# Precision   : 0.2450                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3289                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 7
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.2154                                    Loss        : 4.4487
# Accuracy    : 0.5200                                    Accuracy    : 0.6867
# Precision   : 0.2600                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3421                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 8
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.0890                                    Loss        : 4.3620
# Accuracy    : 0.5286                                    Accuracy    : 0.6867
# Precision   : 0.2643                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3458                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 9
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.5296                                    Loss        : 4.7660
# Accuracy    : 0.4600                                    Accuracy    : 0.6867
# Precision   : 0.2300                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3151                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 10
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.3330                                    Loss        : 4.7297
# Accuracy    : 0.4900                                    Accuracy    : 0.6867
# Precision   : 0.2450                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3289                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 11
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.2689                                    Loss        : 4.6881
# Accuracy    : 0.4900                                    Accuracy    : 0.6867
# Precision   : 0.2450                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3289                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 12
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1895                                    Loss        : 4.6939
# Accuracy    : 0.4700                                    Accuracy    : 0.6867
# Precision   : 0.2350                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3197                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 13
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1754                                    Loss        : 4.5968
# Accuracy    : 0.4943                                    Accuracy    : 0.6867
# Precision   : 0.2471                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3308                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 14
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.2462                                    Loss        : 4.6019
# Accuracy    : 0.4900                                    Accuracy    : 0.6867
# Precision   : 0.2450                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3289                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 15
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.3369                                    Loss        : 4.9460
# Accuracy    : 0.4500                                    Accuracy    : 0.6867
# Precision   : 0.2250                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3103                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 16
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1630                                    Loss        : 4.4707
# Accuracy    : 0.5200                                    Accuracy    : 0.6867
# Precision   : 0.2600                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3421                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 17
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.0035                                    Loss        : 4.5460
# Accuracy    : 0.5086                                    Accuracy    : 0.6867
# Precision   : 0.2543                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3371                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 18
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1693                                    Loss        : 4.5541
# Accuracy    : 0.5186                                    Accuracy    : 0.6867
# Precision   : 0.2593                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3415                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 19
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1478                                    Loss        : 4.7134
# Accuracy    : 0.4514                                    Accuracy    : 0.6867
# Precision   : 0.2257                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3110                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 20
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.3964                                    Loss        : 4.7051
# Accuracy    : 0.4857                                    Accuracy    : 0.6867
# Precision   : 0.2429                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3269                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 21
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1465                                    Loss        : 4.6332
# Accuracy    : 0.5071                                    Accuracy    : 0.6867
# Precision   : 0.2536                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3365                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 22
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1892                                    Loss        : 4.5924
# Accuracy    : 0.5014                                    Accuracy    : 0.6867
# Precision   : 0.2507                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3340                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 23
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1913                                    Loss        : 4.6030
# Accuracy    : 0.4786                                    Accuracy    : 0.6867
# Precision   : 0.2393                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3237                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 24
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.0710                                    Loss        : 4.5667
# Accuracy    : 0.5071                                    Accuracy    : 0.6867
# Precision   : 0.2536                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3365                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 25
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1384                                    Loss        : 4.5201
# Accuracy    : 0.5086                                    Accuracy    : 0.6867
# Precision   : 0.2543                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3371                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 26
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.2662                                    Loss        : 4.5844
# Accuracy    : 0.4829                                    Accuracy    : 0.6867
# Precision   : 0.2414                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3256                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 27
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1453                                    Loss        : 4.6562
# Accuracy    : 0.4743                                    Accuracy    : 0.6867
# Precision   : 0.2371                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3217                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 28
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.0857                                    Loss        : 4.5913
# Accuracy    : 0.4943                                    Accuracy    : 0.6867
# Precision   : 0.2471                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3308                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 29
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1563                                    Loss        : 4.5819
# Accuracy    : 0.4943                                    Accuracy    : 0.6867
# Precision   : 0.2471                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3308                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 30
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1619                                    Loss        : 4.5317
# Accuracy    : 0.5129                                    Accuracy    : 0.6867
# Precision   : 0.2564                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3390                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 31
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1511                                    Loss        : 4.5028
# Accuracy    : 0.5157                                    Accuracy    : 0.6867
# Precision   : 0.2579                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3402                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 32
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 20.8133                                    Loss        : 4.3776
# Accuracy    : 0.5371                                    Accuracy    : 0.6867
# Precision   : 0.2686                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3494                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 33
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.0901                                    Loss        : 4.5023
# Accuracy    : 0.5114                                    Accuracy    : 0.6867
# Precision   : 0.2557                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3384                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 34
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1482                                    Loss        : 4.5305
# Accuracy    : 0.5014                                    Accuracy    : 0.6867
# Precision   : 0.2507                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3340                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 35
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 20.9225                                    Loss        : 4.5093
# ...
# Accuracy    : 0.5043                                    Accuracy    : 0.6867
# Precision   : 0.2521                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3352                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 40
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 20.9651                                    Loss        : 4.4507
# Accuracy    : 0.5157                                    Accuracy    : 0.6867
# Precision   : 0.2579                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3402                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 41
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1921                                    Loss        : 4.5715
# Accuracy    : 0.4971                                    Accuracy    : 0.6867
# Precision   : 0.2486                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3321                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 42
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1710                                    Loss        : 4.4957
# Accuracy    : 0.5086                                    Accuracy    : 0.6867
# Precision   : 0.2543                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3371                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 43
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.2819                                    Loss        : 4.6160
# Accuracy    : 0.4757                                    Accuracy    : 0.6867
# Precision   : 0.2379                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3224                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 44
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.1866                                    Loss        : 4.5905
# Accuracy    : 0.5057                                    Accuracy    : 0.6867
# Precision   : 0.2529                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3359                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 45
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 20.8629                                    Loss        : 4.3934
# Accuracy    : 0.5343                                    Accuracy    : 0.6867
# Precision   : 0.2671                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3482                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 46
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.2764                                    Loss        : 4.5704
# Accuracy    : 0.4900                                    Accuracy    : 0.6867
# Precision   : 0.2450                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3289                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 47
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.0146                                    Loss        : 4.5552
# Accuracy    : 0.4786                                    Accuracy    : 0.6867
# Precision   : 0.2393                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3237                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 48
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 20.9420                                    Loss        : 4.4595
# Accuracy    : 0.5171                                    Accuracy    : 0.6867
# Precision   : 0.2586                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3409                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 49
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.4026                                    Loss        : 4.5942
# Accuracy    : 0.4986                                    Accuracy    : 0.6867
# Precision   : 0.2493                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3327                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 50
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 21.2499                                    Loss        : 4.6894
# Accuracy    : 0.4771                                    Accuracy    : 0.6867
# Precision   : 0.2386                                    Precision   : 0.3433
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3230                                    F1 Score    : 0.4071
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================

# %% [markdown]
# ## Ewaluacja modelu

# %%
from utils.model_functions import eval_torch_model_binary

eval_torch_model_binary(model, criterion, X_test, y_test)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                                              VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 4.6771
# Accuracy    : 0.7133
# Precision   : 0.3567
# Recall      : 0.5000
# F1 Score    : 0.4163
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================

# %% [markdown]
# ## Model Seglearn

# %%
from xgboost import XGBClassifier
from seglearn.pipe import Pype
from seglearn.transform import FeatureRep, Segment

# %%
X_train_np = X_train.numpy()
X_val_np = X_val.numpy()
X_test_np = X_test.numpy()
y_train_np = y_train.numpy()
y_val_np = y_val.numpy()
y_test_np = y_test.numpy()

# %%
X_train_np.shape
# Out:
# (224, 1679, 154)

# %%
y_train_np.shape
# Out:
# (224,)

# %% [markdown]
# ### Budowa modelu

# %%
pipe = Pype([
    ("segment", Segment(width=20, step=10)),  # Segmentacja sekwencji
    ("features", FeatureRep()),              # Ekstrakcja cech
    ("xgb", XGBClassifier(
        eval_metric='logloss',
        n_estimators=200
    ))
])

# %% [markdown]
# ### Trening modelu

# %%
pipe.fit(X_train_np, y_train_np)
# Out:
# Pype(steps=[('segment', Segment(overlap=None, step=10, width=20)),
#             ('features',
#              FeatureRep(features={'abs_energy': <function abs_energy at 0x0000011B25FDCA40>,
#                                   'kurt': <function kurt at 0x0000011B25FDCF40>,
#                                   'max': <function maximum at 0x0000011B25FDCE00>,
#                                   'mean': <function mean at 0x0000011B25FDC680>,
#                                   'median': <function median at 0x0000011B25FDC720>,
#                                   'min': <function minimum at 0x...
#                            gamma=None, grow_policy=None, importance_type=None,
#                            interaction_constraints=None, learning_rate=None,
#                            max_bin=None, max_cat_threshold=None,
#                            max_cat_to_onehot=None, max_delta_step=None,
#                            max_depth=None, max_leaves=None,
#                            min_child_weight=None, missing=nan,
#                            monotone_constraints=None, multi_strategy=None,
#                            n_estimators=200, n_jobs=None,
#                            num_parallel_tree=None, random_state=None, ...))])

# %% [markdown]
# ### Ewaluacja modelu

# %%
val_accuracy = pipe.score(X_val_np, y_val_np)
test_accuracy = pipe.score(X_test_np, y_test_np)

print(f"Dokładność na zbiorze walidacyjnym: {val_accuracy:.2f}")
print(f"Dokładność na zbiorze testowym: {test_accuracy:.2f}")
# Out:
# Dokładność na zbiorze walidacyjnym: 0.43
# Dokładność na zbiorze testowym: 0.50

# %% [markdown]
# # TODYNET

# %% [markdown]
# ### Przygotowanie danych

# %%
X_train_np = X_train.numpy()
X_val_np = X_val.numpy()
X_test_np = X_test.numpy()
y_train_np = y_train.numpy()
y_val_np = y_val.numpy()
y_test_np = y_test.numpy()

# %%
TodyNet_DATA_PATH = os.path.join("..", "..", "src", "external", "TodyNet", "data", "UCR", "SILESIAN_NORMALIZED")

os.makedirs(TodyNet_DATA_PATH, exist_ok=True)

# %%
import torch

X_train_tensor = torch.tensor(X_train_np, dtype=torch.float32).unsqueeze(1)  # adding channel dimension
X_val_tensor = torch.tensor(X_val_np, dtype=torch.float32).unsqueeze(1)
X_test_tensor = torch.tensor(X_test_np, dtype=torch.float32).unsqueeze(1)

# Save the data in PyTorch (.pt) format
torch.save(X_train_tensor, os.path.join(TodyNet_DATA_PATH, 'X_train.pt'))
torch.save(X_val_tensor, os.path.join(TodyNet_DATA_PATH, 'X_valid.pt'))
torch.save(X_test_tensor, os.path.join(TodyNet_DATA_PATH, 'X.pt'))

# Save the labels in PyTorch (.pt) format
torch.save(y_train.long(), os.path.join(TodyNet_DATA_PATH, 'y_train.pt'))
torch.save(y_val.long(), os.path.join(TodyNet_DATA_PATH, 'y_valid.pt'))
torch.save(y_test.long(), os.path.join(TodyNet_DATA_PATH, 'y.pt'))

# %% [markdown]
# ## Trening modelu (zmniejszone parametry ze względu na jego wielkość)

# %%
# cd .\src\external\TodyNet\src\ & python train.py --dataset='SILESIAN_NORMALIZED' --num_layers 1 --in_dim 16 --hidden_dim 16 --out_dim 16 --pool_ratio 0.0 --kern_size "3" --groups 1

# %% [markdown]
# ## Wynik po 120 epokach:
