# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
from utils import get_cuda_info

get_cuda_info()
# Out:
# PyTorch version: 2.5.1+cu118
# **********
# _CUDA version:
# CUDA version:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Wed_Oct_30_01:18:48_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.85
# Build cuda_12.6.r12.6/compiler.35059454_0
#
# **********
# CUDNN version: 90100
# Available GPU devices: 1
# Device Name: NVIDIA GeForce RTX 4070 Ti SUPER

# %% [markdown]
# ## Wybór optymalnych punktów charakterystycznych

# %%
LANDMARK_INDEXES = [
    76, 306,  # mouth corners
    74, 73, 72, 11, 302, 303, 304, # upper lip
    90, 180, 85, 16, 315, 404, 320, # lower lip
    33, 161, 159, 157, 133, 154, 145, 163,  # left eye
    70, 63, 105, 66, 107,  # left eyebrow
    362, 384, 386, 388, 263, 390, 374, 381,  # right eye
    300, 293, 334, 296, 336,  # right eyebrow
    1, 5, 197, 168  # nose
]

# %% [markdown]
# ### Wizualizacja wybranych punktów

# %%
from utils import visualize_landmarks

visualize_landmarks(LANDMARK_INDEXES)

# %% [markdown]
# ## Zdobycie danych

# %%
from utils import load_data, get_selected_landmarks

all_data, all_labels = load_data('ravdess')
all_data = get_selected_landmarks(all_data, LANDMARK_INDEXES)

# %% [markdown]
# ## Preprocessing danych

# %%
from utils import preprocess_data

X_train, X_val, X_test, y_train, y_val, y_test = preprocess_data(all_data, all_labels)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([2012, 157, 46, 2])
# torch.Size([2012, 8])

# %% [markdown]
# # MODEL TORCH

# %% [markdown]
# ## Zbudowanie modelu ekstrakcji cech

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class EmotionClassifier(nn.Module):
    def __init__(self):
        super(EmotionClassifier, self).__init__()

        # Spatial feature extraction using Conv1D
        self.conv1 = nn.Conv1d(in_channels=2, out_channels=32, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool1d(kernel_size=2)
        
        # LSTM layers for temporal feature extraction
        self.lstm1 = nn.LSTM(input_size=736, hidden_size=128, batch_first=True, bidirectional=True)
        self.lstm2 = nn.LSTM(input_size=128 * 2, hidden_size=64, batch_first=True)
        
        # Fully connected classification layer
        self.fc = nn.Linear(64, 8)  # 8 emotion classes

    def forward(self, x):
        # x shape: (batch_size, frames, landmarks, coordinates)
        batch_size, frames, landmarks, coordinates = x.shape
        
        # Reshape for Conv1D: (batch_size * frames, landmarks, coordinates)
        x = x.view(-1, landmarks, coordinates).permute(0, 2, 1)
        
        # Spatial feature extraction
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        
        # Flatten spatial features
        x = x.view(batch_size, frames, -1)  # (batch_size, frames, features)
        
        # Temporal feature extraction
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        
        # Classification
        x = self.fc(x[:, -1, :])  # Take the last timestep's output
        return x

# %%
from torch.optim import Adam

model = EmotionClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# ## Trening modelu

# %%
from torch.utils.tensorboard import SummaryWriter

RUNS_FOLDER_PATH = os.path.abspath('runs')
writer_path = os.path.join('runs', 'torch_lstm', 'emotion_classifier_selected_landmarks')
writer = SummaryWriter(writer_path)

# %%
from utils.model_functions import train_torch_model_multiclass

train_torch_model_multiclass(model, criterion, optimizer, X_train, y_train, X_val, y_val, writer=writer)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.493864                                    Loss        : 28.895126
# Accuracy    : 0.1352                                    Accuracy    : 0.1276
# Precision   : 0.0341                                    Precision   : 0.0160
# Recall      : 0.1243                                    Recall      : 0.1250
# F1 Score    : 0.0433                                    F1 Score    : 0.0283
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 2
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.119909                                    Loss        : 28.866852
# Accuracy    : 0.1337                                    Accuracy    : 0.1276
# Precision   : 0.0170                                    Precision   : 0.0160
# Recall      : 0.1210                                    Recall      : 0.1250
# F1 Score    : 0.0298                                    F1 Score    : 0.0283
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 3
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.054879                                    Loss        : 28.860782
# Accuracy    : 0.1228                                    Accuracy    : 0.1276
# Precision   : 0.0463                                    Precision   : 0.0160
# Recall      : 0.1124                                    Recall      : 0.1250
# F1 Score    : 0.0648                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 4
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.026988                                    Loss        : 28.859768
# Accuracy    : 0.1387                                    Accuracy    : 0.1276
# Precision   : 0.0798                                    Precision   : 0.0160
# Recall      : 0.1255                                    Recall      : 0.1250
# F1 Score    : 0.0313                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 5
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.015219                                    Loss        : 28.865200
# Accuracy    : 0.1357                                    Accuracy    : 0.1276
# Precision   : 0.0339                                    Precision   : 0.0160
# Recall      : 0.1245                                    Recall      : 0.1250
# F1 Score    : 0.0501                                    F1 Score    : 0.0283
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 6
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.068137                                    Loss        : 28.857208
# Accuracy    : 0.1287                                    Accuracy    : 0.1462
# Precision   : 0.1705                                    Precision   : 0.0183
# Recall      : 0.1181                                    Recall      : 0.1250
# F1 Score    : 0.0635                                    F1 Score    : 0.0319
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 7
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.053644                                    Loss        : 28.860001
# Accuracy    : 0.1347                                    Accuracy    : 0.1276
# Precision   : 0.0475                                    Precision   : 0.0160
# Recall      : 0.1233                                    Recall      : 0.1250
# F1 Score    : 0.0575                                    F1 Score    : 0.0283
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 8
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.024569                                    Loss        : 28.863603
# Accuracy    : 0.1252                                    Accuracy    : 0.1276
# Precision   : 0.0380                                    Precision   : 0.0160
# Recall      : 0.1138                                    Recall      : 0.1250
# F1 Score    : 0.0467                                    F1 Score    : 0.0283
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 9
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.077583                                    Loss        : 28.854626
# Accuracy    : 0.1257                                    Accuracy    : 0.1462
# Precision   : 0.1074                                    Precision   : 0.0183
# Recall      : 0.1147                                    Recall      : 0.1250
# F1 Score    : 0.0543                                    F1 Score    : 0.0319
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 10
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.016821                                    Loss        : 28.867987
# Accuracy    : 0.1327                                    Accuracy    : 0.1276
# Precision   : 0.1732                                    Precision   : 0.0160
# Recall      : 0.1215                                    Recall      : 0.1250
# F1 Score    : 0.0646                                    F1 Score    : 0.0283
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 11
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.026463                                    Loss        : 28.857673
# Accuracy    : 0.1257                                    Accuracy    : 0.1462
# Precision   : 0.0442                                    Precision   : 0.0183
# Recall      : 0.1145                                    Recall      : 0.1250
# F1 Score    : 0.0561                                    F1 Score    : 0.0319
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 12
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.016809                                    Loss        : 28.861777
# Accuracy    : 0.1272                                    Accuracy    : 0.1276
# Precision   : 0.0976                                    Precision   : 0.0160
# Recall      : 0.1159                                    Recall      : 0.1250
# F1 Score    : 0.0494                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 13
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.025599                                    Loss        : 28.862202
# Accuracy    : 0.1262                                    Accuracy    : 0.1276
# Precision   : 0.0942                                    Precision   : 0.0160
# Recall      : 0.1158                                    Recall      : 0.1250
# F1 Score    : 0.0505                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 14
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.067917                                    Loss        : 28.872975
# Accuracy    : 0.1307                                    Accuracy    : 0.1346
# Precision   : 0.0256                                    Precision   : 0.1099
# Recall      : 0.1203                                    Recall      : 0.1314
# F1 Score    : 0.0350                                    F1 Score    : 0.0404
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 15
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.024570                                    Loss        : 28.861824
# Accuracy    : 0.1387                                    Accuracy    : 0.1276
# Precision   : 0.1423                                    Precision   : 0.0160
# Recall      : 0.1255                                    Recall      : 0.1250
# F1 Score    : 0.0313                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 16
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.018614                                    Loss        : 28.860079
# Accuracy    : 0.1387                                    Accuracy    : 0.1276
# Precision   : 0.0798                                    Precision   : 0.0160
# Recall      : 0.1255                                    Recall      : 0.1250
# F1 Score    : 0.0313                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 17
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.021961                                    Loss        : 28.860617
# Accuracy    : 0.1387                                    Accuracy    : 0.1276
# Precision   : 0.0798                                    Precision   : 0.0160
# Recall      : 0.1255                                    Recall      : 0.1250
# F1 Score    : 0.0313                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 18
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 129.991289                                    Loss        : 28.861805
# Accuracy    : 0.1382                                    Accuracy    : 0.1276
# Precision   : 0.0797                                    Precision   : 0.0160
# Recall      : 0.1250                                    Recall      : 0.1250
# F1 Score    : 0.0312                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 19
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.000964                                    Loss        : 28.858079
# Accuracy    : 0.1307                                    Accuracy    : 0.1299
# Precision   : 0.0927                                    Precision   : 0.0785
# Recall      : 0.1189                                    Recall      : 0.1271
# F1 Score    : 0.0471                                    F1 Score    : 0.0325
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 20
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 129.991497                                    Loss        : 28.863133
# Accuracy    : 0.1292                                    Accuracy    : 0.1299
# Precision   : 0.0503                                    Precision   : 0.0785
# Recall      : 0.1191                                    Recall      : 0.1271
# F1 Score    : 0.0454                                    F1 Score    : 0.0325
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 21
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 130.002563                                    Loss        : 28.858760
# Accuracy    : 0.1337                                    Accuracy    : 0.1276
# Precision   : 0.0886                                    Precision   : 0.0160
# Recall      : 0.1211                                    Recall      : 0.1250
# F1 Score    : 0.0365                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 22
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 129.988034                                    Loss        : 28.863026
# Accuracy    : 0.1387                                    Accuracy    : 0.1276
# Precision   : 0.0798                                    Precision   : 0.0160
# Recall      : 0.1255                                    Recall      : 0.1250
# F1 Score    : 0.0313                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 23
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 129.999308                                    Loss        : 28.852528
# Accuracy    : 0.1267                                    Accuracy    : 0.1485
# Precision   : 0.0407                                    Precision   : 0.0809
# Recall      : 0.1151                                    Recall      : 0.1271
# F1 Score    : 0.0520                                    F1 Score    : 0.0361
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 24
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 129.988315                                    Loss        : 28.864550
# Accuracy    : 0.1357                                    Accuracy    : 0.1276
# Precision   : 0.0655                                    Precision   : 0.0160
# Recall      : 0.1230                                    Recall      : 0.1250
# F1 Score    : 0.0431                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 25
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 129.981471                                    Loss        : 28.859436
# Accuracy    : 0.1297                                    Accuracy    : 0.1276
# Precision   : 0.0633                                    Precision   : 0.0160
# Recall      : 0.1199                                    Recall      : 0.1250
# F1 Score    : 0.0511                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 26
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 129.986256                                    Loss        : 28.854745
# Accuracy    : 0.1337                                    Accuracy    : 0.1276
# Precision   : 0.0266                                    Precision   : 0.0160
# Recall      : 0.1210                                    Recall      : 0.1250
# F1 Score    : 0.0362                                    F1 Score    : 0.0284
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 27
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 129.890630                                    Loss        : 28.784153
# Accuracy    : 0.1486                                    Accuracy    : 0.1717
# Precision   : 0.0490                                    Precision   : 0.0482
# Recall      : 0.1353                                    Recall      : 0.1639
# F1 Score    : 0.0610                                    F1 Score    : 0.0709
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 28
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 128.506907                                    Loss        : 28.067534
# Accuracy    : 0.1869                                    Accuracy    : 0.1972
# Precision   : 0.0839                                    Precision   : 0.0687
# Recall      : 0.1717                                    Recall      : 0.1910
# F1 Score    : 0.0978                                    F1 Score    : 0.0956
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 29
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 125.402899                                    Loss        : 27.565161
# Accuracy    : 0.1918                                    Accuracy    : 0.1926
# Precision   : 0.1032                                    Precision   : 0.1241
# Recall      : 0.1800                                    Recall      : 0.1838
# F1 Score    : 0.1148                                    F1 Score    : 0.1222
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 30
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 123.578829                                    Loss        : 27.292703
# Accuracy    : 0.2117                                    Accuracy    : 0.1833
# Precision   : 0.1642                                    Precision   : 0.1055
# Recall      : 0.1966                                    Recall      : 0.1749
# F1 Score    : 0.1448                                    F1 Score    : 0.1191
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 31
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.995452                                    Loss        : 27.507309
# Accuracy    : 0.2247                                    Accuracy    : 0.2088
# Precision   : 0.1802                                    Precision   : 0.1166
# Recall      : 0.2106                                    Recall      : 0.2006
# F1 Score    : 0.1551                                    F1 Score    : 0.1241
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 32
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.695275                                    Loss        : 27.470709
# Accuracy    : 0.2182                                    Accuracy    : 0.2019
# Precision   : 0.1468                                    Precision   : 0.1160
# Recall      : 0.2048                                    Recall      : 0.1949
# F1 Score    : 0.1529                                    F1 Score    : 0.1146
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 33
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.615606                                    Loss        : 27.299658
# Accuracy    : 0.2192                                    Accuracy    : 0.2088
# Precision   : 0.1463                                    Precision   : 0.1078
# Recall      : 0.2059                                    Recall      : 0.1975
# F1 Score    : 0.1422                                    F1 Score    : 0.1298
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 34
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.453847                                    Loss        : 27.330231
# Accuracy    : 0.2202                                    Accuracy    : 0.1995
# Precision   : 0.1660                                    Precision   : 0.1315
# Recall      : 0.2061                                    Recall      : 0.1883
# F1 Score    : 0.1476                                    F1 Score    : 0.1449
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 35
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.381793                                    Loss        : 27.371294
# Accuracy    : 0.2212                                    Accuracy    : 0.1879
# Precision   : 0.1366                                    Precision   : 0.1187
# Recall      : 0.2074                                    Recall      : 0.1780
# F1 Score    : 0.1437                                    F1 Score    : 0.1215
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 36
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.411535                                    Loss        : 27.304963
# Accuracy    : 0.2202                                    Accuracy    : 0.1995
# Precision   : 0.1539                                    Precision   : 0.0977
# Recall      : 0.2064                                    Recall      : 0.1903
# F1 Score    : 0.1341                                    F1 Score    : 0.1152
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 37
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.131672                                    Loss        : 27.282730
# Accuracy    : 0.2291                                    Accuracy    : 0.1926
# Precision   : 0.1162                                    Precision   : 0.0941
# Recall      : 0.2148                                    Recall      : 0.1817
# F1 Score    : 0.1394                                    F1 Score    : 0.1215
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 38
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.073666                                    Loss        : 27.241612
# Accuracy    : 0.2207                                    Accuracy    : 0.1926
# Precision   : 0.1188                                    Precision   : 0.0952
# Recall      : 0.2069                                    Recall      : 0.1820
# F1 Score    : 0.1412                                    F1 Score    : 0.1216
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 39
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.236356                                    Loss        : 27.259087
# Accuracy    : 0.2217                                    Accuracy    : 0.2042
# Precision   : 0.1688                                    Precision   : 0.1157
# Recall      : 0.2073                                    Recall      : 0.1950
# F1 Score    : 0.1660                                    F1 Score    : 0.1267
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 40
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.343135                                    Loss        : 27.255000
# Accuracy    : 0.2127                                    Accuracy    : 0.1995
# Precision   : 0.1220                                    Precision   : 0.1187
# Recall      : 0.1996                                    Recall      : 0.1895
# F1 Score    : 0.1422                                    F1 Score    : 0.1267
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 41
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.289026                                    Loss        : 27.245722
# Accuracy    : 0.2177                                    Accuracy    : 0.1879
# Precision   : 0.1600                                    Precision   : 0.0908
# Recall      : 0.2050                                    Recall      : 0.1771
# F1 Score    : 0.1489                                    F1 Score    : 0.1187
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 42
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 122.052606                                    Loss        : 27.203889
# Accuracy    : 0.2247                                    Accuracy    : 0.1972
# Precision   : 0.1274                                    Precision   : 0.1196
# Recall      : 0.2104                                    Recall      : 0.1872
# F1 Score    : 0.1465                                    F1 Score    : 0.1319
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 43
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 121.968743                                    Loss        : 27.249425
# Accuracy    : 0.2172                                    Accuracy    : 0.1972
# Precision   : 0.1251                                    Precision   : 0.0918
# Recall      : 0.2034                                    Recall      : 0.1870
# F1 Score    : 0.1420                                    F1 Score    : 0.1196
# ...
# Precision   : 0.5104                                    Precision   : 0.4933
# Recall      : 0.5168                                    Recall      : 0.4660
# F1 Score    : 0.5092                                    F1 Score    : 0.4614
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 287
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 79.131737                                    Loss        : 19.922101
# Accuracy    : 0.5358                                    Accuracy    : 0.4524
# Precision   : 0.5187                                    Precision   : 0.4725
# Recall      : 0.5207                                    Recall      : 0.4341
# F1 Score    : 0.5144                                    F1 Score    : 0.4250
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 288
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 81.268007                                    Loss        : 19.283729
# Accuracy    : 0.5144                                    Accuracy    : 0.4571
# Precision   : 0.4937                                    Precision   : 0.4324
# Recall      : 0.4999                                    Recall      : 0.4316
# F1 Score    : 0.4940                                    F1 Score    : 0.4122
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 289
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 82.717256                                    Loss        : 17.855139
# Accuracy    : 0.4940                                    Accuracy    : 0.5104
# Precision   : 0.4689                                    Precision   : 0.5004
# Recall      : 0.4792                                    Recall      : 0.4989
# F1 Score    : 0.4702                                    F1 Score    : 0.4941
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 290
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 80.886572                                    Loss        : 17.569459
# Accuracy    : 0.5109                                    Accuracy    : 0.5174
# Precision   : 0.4882                                    Precision   : 0.4898
# Recall      : 0.4949                                    Recall      : 0.5004
# F1 Score    : 0.4889                                    F1 Score    : 0.4912
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 291
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 79.657908                                    Loss        : 18.896060
# Accuracy    : 0.5224                                    Accuracy    : 0.4664
# Precision   : 0.5010                                    Precision   : 0.4492
# Recall      : 0.5090                                    Recall      : 0.4413
# F1 Score    : 0.5033                                    F1 Score    : 0.4315
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 292
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 80.861316                                    Loss        : 18.338526
# Accuracy    : 0.5164                                    Accuracy    : 0.4896
# Precision   : 0.4903                                    Precision   : 0.4794
# Recall      : 0.5002                                    Recall      : 0.4693
# F1 Score    : 0.4911                                    F1 Score    : 0.4616
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 293
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 80.493685                                    Loss        : 18.039700
# Accuracy    : 0.5040                                    Accuracy    : 0.5128
# Precision   : 0.4874                                    Precision   : 0.5071
# Recall      : 0.4878                                    Recall      : 0.5009
# F1 Score    : 0.4838                                    F1 Score    : 0.4957
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 294
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 77.685592                                    Loss        : 19.236800
# Accuracy    : 0.5383                                    Accuracy    : 0.4594
# Precision   : 0.5144                                    Precision   : 0.4772
# Recall      : 0.5235                                    Recall      : 0.4562
# F1 Score    : 0.5144                                    F1 Score    : 0.4536
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 295
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 79.583703                                    Loss        : 17.712492
# Accuracy    : 0.5244                                    Accuracy    : 0.5313
# Precision   : 0.5001                                    Precision   : 0.5173
# Recall      : 0.5060                                    Recall      : 0.5225
# F1 Score    : 0.5004                                    F1 Score    : 0.5155
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 296
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 77.563092                                    Loss        : 19.805727
# Accuracy    : 0.5383                                    Accuracy    : 0.4849
# Precision   : 0.5147                                    Precision   : 0.4874
# Recall      : 0.5206                                    Recall      : 0.4617
# F1 Score    : 0.5136                                    F1 Score    : 0.4428
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 297
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 79.236916                                    Loss        : 17.804424
# Accuracy    : 0.5268                                    Accuracy    : 0.4826
# Precision   : 0.5070                                    Precision   : 0.4414
# Recall      : 0.5155                                    Recall      : 0.4560
# F1 Score    : 0.5076                                    F1 Score    : 0.4367
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 298
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 79.456241                                    Loss        : 17.358092
# Accuracy    : 0.5239                                    Accuracy    : 0.5174
# Precision   : 0.5035                                    Precision   : 0.5119
# Recall      : 0.5109                                    Recall      : 0.5108
# F1 Score    : 0.5058                                    F1 Score    : 0.5035
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 299
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 76.364538                                    Loss        : 17.905617
# Accuracy    : 0.5462                                    Accuracy    : 0.5197
# Precision   : 0.5231                                    Precision   : 0.5208
# Recall      : 0.5329                                    Recall      : 0.5069
# F1 Score    : 0.5256                                    F1 Score    : 0.5049
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 300
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 77.422113                                    Loss        : 18.407502
# Accuracy    : 0.5363                                    Accuracy    : 0.4872
# Precision   : 0.5198                                    Precision   : 0.4741
# Recall      : 0.5253                                    Recall      : 0.4727
# F1 Score    : 0.5193                                    F1 Score    : 0.4630
# ====================================================================================================

# %% [markdown]
# ## Ewaluacja modelu

# %%
from utils.model_functions import eval_torch_model_multiclass

eval_torch_model_multiclass(model, criterion, X_test, y_test)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                                              VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 18.478500
# Accuracy    : 0.4931
# Precision   : 0.4567
# Recall      : 0.4621
# F1 Score    : 0.4538
# ====================================================================================================
