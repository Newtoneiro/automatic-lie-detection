# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

# %%
from utils import get_cuda_info

get_cuda_info()
# Out:
# PyTorch version: 2.5.1+cu118
# **********
# _CUDA version:
# CUDA version:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Wed_Oct_30_01:18:48_Pacific_Daylight_Time_2024
# Cuda compilation tools, release 12.6, V12.6.85
# Build cuda_12.6.r12.6/compiler.35059454_0
#
# **********
# CUDNN version: 90100
# Available GPU devices: 1
# Device Name: NVIDIA GeForce RTX 4070 Ti SUPER

# %% [markdown]
# ## Zdobycie danych

# %%
from utils import load_data, convert_landmarks_to_eye_movements

all_data, all_labels = load_data('miami_deception')

# %%
converted_data, blinks = convert_landmarks_to_eye_movements(all_data)

# %% [markdown]
# ## Ograniczenie do pierwszych N klatek i normalizacja per próbkę

# %%
import numpy as np

def normalize_sample(data):
    mean = np.mean(data, axis=(0, 1), keepdims=True)
    std = np.std(data, axis=(0, 1), keepdims=True)
    normalized = (data - mean) / (std + 1e-8)
    return normalized

# %%
normalized_cut_data = np.array([normalize_sample(d[:1000, :]) for d in converted_data], dtype=object)

# %% [markdown]
# ## Preprocessing danych

# %%
from utils import preprocess_data

X_train, X_val, X_test, y_train, y_val, y_test = preprocess_data(normalized_cut_data, all_labels, binarize_labels=False)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# torch.Size([224, 1000, 2])
# torch.Size([224])

# %%
from utils import get_class_distribution

get_class_distribution(all_labels)
# Out:
# ===> Class distribution <===
# 0: 160
# 1: 160
# =============><=============

# %%
X_train[4].min()
# Out:
# tensor(-1.9428)

# %% [markdown]
# # MODEL TORCH

# %% [markdown]
# ## Zbudowanie modelu ekstrakcji cech

# %%
import torch
import torch.nn as nn

# %%
class EyeDirectionTransformerClassifier(nn.Module):
    def __init__(self, d_model=64, nhead=4, num_layers=2, dim_feedforward=128, dropout=0.1):
        super().__init__()
        
        self.input_proj = nn.Linear(2, d_model)  # Project (dir_x, dir_y) to d_model
        
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=nhead,
            dim_feedforward=dim_feedforward,
            dropout=dropout,
            batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        
        self.cls_head = nn.Sequential(
            nn.Linear(d_model, 32),
            nn.ReLU(),
            nn.Linear(32, 1)  # Binary classification
        )

    def forward(self, x):
        # x: [batch, seq_len, 2]
        x = self.input_proj(x)  # -> [batch, seq_len, d_model]
        x = self.transformer_encoder(x)  # -> [batch, seq_len, d_model]
        x = x.mean(dim=1)  # Global average pooling over time
        out = self.cls_head(x)  # -> [batch, 1]
        return out

# %%
from torch.optim import Adam

model = EyeDirectionTransformerClassifier()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
pos_weight = torch.tensor([(len(y_train) - y_train.sum()) / y_train.sum()]).to(device)
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)
optimizer = Adam(model.parameters(), lr=1e-4)

# %% [markdown]
# ## Trening modelu

# %%
from torch.utils.tensorboard import SummaryWriter

RUNS_FOLDER_PATH = os.path.abspath('runs')
writer_path = os.path.join('runs',  model.__class__.__qualname__, 'eye_movement')
writer = SummaryWriter(writer_path)

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
from utils.model_functions import train_torch_model_binary

train_torch_model_binary(model, criterion, optimizer, X_train, y_train, X_val, y_val, writer=writer, batch_size=128, unbalanced=True, show_prediction_stats=False, epochs=1000)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3687                                    Loss        : 0.7066
# Accuracy    : 0.4509                                    Accuracy    : 0.3542
# Precision   : 0.2254                                    Precision   : 0.1771
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3108                                    F1 Score    : 0.2615
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 2
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3263                                    Loss        : 0.6987
# Accuracy    : 0.5312                                    Accuracy    : 0.3542
# Precision   : 0.2656                                    Precision   : 0.1771
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3469                                    F1 Score    : 0.2615
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 3
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3277                                    Loss        : 0.6917
# Accuracy    : 0.4955                                    Accuracy    : 0.3542
# Precision   : 0.2478                                    Precision   : 0.1771
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3313                                    F1 Score    : 0.2615
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 4
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3080                                    Loss        : 0.6863
# Accuracy    : 0.5357                                    Accuracy    : 0.3542
# Precision   : 0.2679                                    Precision   : 0.1771
# Recall      : 0.5000                                    Recall      : 0.5000
# F1 Score    : 0.3488                                    F1 Score    : 0.2615
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 1.0000                                    FP Rate     : 1.0000
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 5
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3323                                    Loss        : 0.6807
# Accuracy    : 0.4554                                    Accuracy    : 0.3958
# Precision   : 0.2277                                    Precision   : 0.5568
# Recall      : 0.5000                                    Recall      : 0.5190
# F1 Score    : 0.3129                                    F1 Score    : 0.3480
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.9412                                    FP Rate     : 0.9032
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 6
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3139                                    Loss        : 0.6752
# Accuracy    : 0.5134                                    Accuracy    : 0.4583
# Precision   : 0.5326                                    Precision   : 0.4643
# Recall      : 0.5213                                    Recall      : 0.4611
# F1 Score    : 0.4716                                    F1 Score    : 0.4497
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.4706                                    FP Rate     : 0.5484
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 7
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3121                                    Loss        : 0.6707
# Accuracy    : 0.5625                                    Accuracy    : 0.5000
# Precision   : 0.5611                                    Precision   : 0.4535
# Recall      : 0.5608                                    Recall      : 0.4535
# F1 Score    : 0.5608                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 8
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3090                                    Loss        : 0.6668
# Accuracy    : 0.5893                                    Accuracy    : 0.5208
# Precision   : 0.5950                                    Precision   : 0.4517
# Recall      : 0.5830                                    Recall      : 0.4564
# F1 Score    : 0.5728                                    F1 Score    : 0.4521
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2353                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 9
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3016                                    Loss        : 0.6642
# Accuracy    : 0.5580                                    Accuracy    : 0.5208
# Precision   : 0.6127                                    Precision   : 0.4517
# Recall      : 0.5762                                    Recall      : 0.4564
# F1 Score    : 0.5274                                    F1 Score    : 0.4521
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2353                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 10
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3117                                    Loss        : 0.6628
# Accuracy    : 0.5134                                    Accuracy    : 0.5208
# Precision   : 0.5269                                    Precision   : 0.4517
# Recall      : 0.5184                                    Recall      : 0.4564
# F1 Score    : 0.4744                                    F1 Score    : 0.4521
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2353                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 11
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3082                                    Loss        : 0.6609
# Accuracy    : 0.5268                                    Accuracy    : 0.5000
# Precision   : 0.5165                                    Precision   : 0.4154
# Recall      : 0.5101                                    Recall      : 0.4269
# F1 Score    : 0.4652                                    F1 Score    : 0.4182
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.1765                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 12
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2978                                    Loss        : 0.6600
# Accuracy    : 0.5491                                    Accuracy    : 0.5000
# Precision   : 0.5735                                    Precision   : 0.4154
# Recall      : 0.5464                                    Recall      : 0.4269
# F1 Score    : 0.5018                                    F1 Score    : 0.4182
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.1765                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 13
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3018                                    Loss        : 0.6602
# Accuracy    : 0.5089                                    Accuracy    : 0.5208
# Precision   : 0.5501                                    Precision   : 0.4517
# Recall      : 0.5371                                    Recall      : 0.4564
# F1 Score    : 0.4873                                    F1 Score    : 0.4521
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2353                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 14
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3026                                    Loss        : 0.6606
# Accuracy    : 0.5268                                    Accuracy    : 0.5208
# Precision   : 0.5172                                    Precision   : 0.4517
# Recall      : 0.5120                                    Recall      : 0.4564
# F1 Score    : 0.4787                                    F1 Score    : 0.4521
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2353                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 15
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3085                                    Loss        : 0.6612
# Accuracy    : 0.5089                                    Accuracy    : 0.5208
# Precision   : 0.5408                                    Precision   : 0.4517
# Recall      : 0.5272                                    Recall      : 0.4564
# F1 Score    : 0.4736                                    F1 Score    : 0.4521
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2353                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 16
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3083                                    Loss        : 0.6618
# Accuracy    : 0.5491                                    Accuracy    : 0.5208
# Precision   : 0.5645                                    Precision   : 0.4517
# Recall      : 0.5441                                    Recall      : 0.4564
# F1 Score    : 0.5076                                    F1 Score    : 0.4521
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2353                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 17
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3092                                    Loss        : 0.6622
# Accuracy    : 0.5402                                    Accuracy    : 0.5208
# Precision   : 0.5556                                    Precision   : 0.4517
# Recall      : 0.5402                                    Recall      : 0.4564
# F1 Score    : 0.5059                                    F1 Score    : 0.4521
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2353                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 18
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2978                                    Loss        : 0.6641
# Accuracy    : 0.5446                                    Accuracy    : 0.5417
# Precision   : 0.5947                                    Precision   : 0.4848
# Recall      : 0.5630                                    Recall      : 0.4858
# F1 Score    : 0.5119                                    F1 Score    : 0.4844
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3226
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 19
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3169                                    Loss        : 0.6664
# Accuracy    : 0.5268                                    Accuracy    : 0.5208
# Precision   : 0.5441                                    Precision   : 0.4688
# Recall      : 0.5374                                    Recall      : 0.4696
# F1 Score    : 0.5128                                    F1 Score    : 0.4690
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3548
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 20
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3069                                    Loss        : 0.6690
# Accuracy    : 0.5446                                    Accuracy    : 0.5000
# Precision   : 0.5676                                    Precision   : 0.4535
# Recall      : 0.5603                                    Recall      : 0.4535
# F1 Score    : 0.5374                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 21
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2999                                    Loss        : 0.6719
# Accuracy    : 0.5580                                    Accuracy    : 0.4792
# Precision   : 0.5795                                    Precision   : 0.4389
# Recall      : 0.5656                                    Recall      : 0.4374
# F1 Score    : 0.5411                                    F1 Score    : 0.4379
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.4194
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 22
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3006                                    Loss        : 0.6736
# Accuracy    : 0.5759                                    Accuracy    : 0.4792
# Precision   : 0.5825                                    Precision   : 0.4389
# Recall      : 0.5709                                    Recall      : 0.4374
# F1 Score    : 0.5581                                    F1 Score    : 0.4379
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.4194
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 23
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3026                                    Loss        : 0.6735
# Accuracy    : 0.5714                                    Accuracy    : 0.4792
# Precision   : 0.5597                                    Precision   : 0.4389
# Recall      : 0.5519                                    Recall      : 0.4374
# F1 Score    : 0.5450                                    F1 Score    : 0.4379
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.4194
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 24
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3108                                    Loss        : 0.6734
# Accuracy    : 0.5536                                    Accuracy    : 0.4792
# Precision   : 0.5586                                    Precision   : 0.4389
# Recall      : 0.5568                                    Recall      : 0.4374
# F1 Score    : 0.5513                                    F1 Score    : 0.4379
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.4194
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 25
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2890                                    Loss        : 0.6724
# Accuracy    : 0.5848                                    Accuracy    : 0.4792
# Precision   : 0.5914                                    Precision   : 0.4389
# Recall      : 0.5781                                    Recall      : 0.4374
# F1 Score    : 0.5657                                    F1 Score    : 0.4379
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.4194
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 26
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2996                                    Loss        : 0.6722
# Accuracy    : 0.5580                                    Accuracy    : 0.4792
# Precision   : 0.5744                                    Precision   : 0.4389
# Recall      : 0.5678                                    Recall      : 0.4374
# F1 Score    : 0.5515                                    F1 Score    : 0.4379
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.4194
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 27
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2978                                    Loss        : 0.6703
# Accuracy    : 0.6116                                    Accuracy    : 0.5000
# Precision   : 0.5955                                    Precision   : 0.4535
# Recall      : 0.5873                                    Recall      : 0.4535
# F1 Score    : 0.5867                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 28
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2886                                    Loss        : 0.6689
# Accuracy    : 0.5848                                    Accuracy    : 0.5000
# Precision   : 0.6075                                    Precision   : 0.4535
# Recall      : 0.5918                                    Recall      : 0.4535
# F1 Score    : 0.5718                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 29
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2911                                    Loss        : 0.6689
# Accuracy    : 0.5804                                    Accuracy    : 0.5000
# Precision   : 0.6130                                    Precision   : 0.4535
# Recall      : 0.5888                                    Recall      : 0.4535
# F1 Score    : 0.5602                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 30
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3273                                    Loss        : 0.6686
# Accuracy    : 0.4955                                    Accuracy    : 0.5000
# Precision   : 0.4758                                    Precision   : 0.4535
# Recall      : 0.4810                                    Recall      : 0.4535
# F1 Score    : 0.4579                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 31
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3099                                    Loss        : 0.6690
# Accuracy    : 0.5045                                    Accuracy    : 0.5000
# Precision   : 0.5263                                    Precision   : 0.4535
# Recall      : 0.5234                                    Recall      : 0.4535
# F1 Score    : 0.4972                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 32
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3221                                    Loss        : 0.6693
# Accuracy    : 0.5045                                    Accuracy    : 0.5000
# Precision   : 0.5116                                    Precision   : 0.4535
# Recall      : 0.5104                                    Recall      : 0.4535
# F1 Score    : 0.4935                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 33
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.3169                                    Loss        : 0.6684
# Accuracy    : 0.5223                                    Accuracy    : 0.5000
# Precision   : 0.5184                                    Precision   : 0.4535
# Recall      : 0.5164                                    Recall      : 0.4535
# F1 Score    : 0.5058                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 34
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2923                                    Loss        : 0.6684
# Accuracy    : 0.5670                                    Accuracy    : 0.5000
# Precision   : 0.5820                                    Precision   : 0.4535
# Recall      : 0.5751                                    Recall      : 0.4535
# F1 Score    : 0.5606                                    F1 Score    : 0.4535
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.2941                                    FP Rate     : 0.3871
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 35
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 1.2970                                    Loss        : 0.6679
# ...
# Accuracy    : 0.9018                                    Accuracy    : 0.3958
# Precision   : 0.9020                                    Precision   : 0.3958
# Recall      : 0.9017                                    Recall      : 0.3861
# F1 Score    : 0.9018                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 990
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.6172                                    Loss        : 1.5844
# Accuracy    : 0.8527                                    Accuracy    : 0.3958
# Precision   : 0.8527                                    Precision   : 0.3958
# Recall      : 0.8575                                    Recall      : 0.3861
# F1 Score    : 0.8522                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 991
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.4756                                    Loss        : 1.5773
# Accuracy    : 0.8527                                    Accuracy    : 0.3958
# Precision   : 0.8516                                    Precision   : 0.3958
# Recall      : 0.8491                                    Recall      : 0.3861
# F1 Score    : 0.8502                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 992
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.6064                                    Loss        : 1.5890
# Accuracy    : 0.8571                                    Accuracy    : 0.3958
# Precision   : 0.8563                                    Precision   : 0.3958
# Recall      : 0.8584                                    Recall      : 0.3861
# F1 Score    : 0.8567                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 993
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.5246                                    Loss        : 1.6308
# Accuracy    : 0.8839                                    Accuracy    : 0.3958
# Precision   : 0.8833                                    Precision   : 0.3958
# Recall      : 0.8840                                    Recall      : 0.3861
# F1 Score    : 0.8836                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 994
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.5493                                    Loss        : 1.6339
# Accuracy    : 0.8884                                    Accuracy    : 0.3958
# Precision   : 0.8883                                    Precision   : 0.3958
# Recall      : 0.8880                                    Recall      : 0.3861
# F1 Score    : 0.8881                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 995
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.6063                                    Loss        : 1.6242
# Accuracy    : 0.8795                                    Accuracy    : 0.3958
# Precision   : 0.8785                                    Precision   : 0.3958
# Recall      : 0.8813                                    Recall      : 0.3861
# F1 Score    : 0.8791                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 996
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.5080                                    Loss        : 1.6175
# Accuracy    : 0.9018                                    Accuracy    : 0.3958
# Precision   : 0.9013                                    Precision   : 0.3958
# Recall      : 0.9013                                    Recall      : 0.3861
# F1 Score    : 0.9013                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 997
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.7274                                    Loss        : 1.6108
# Accuracy    : 0.8348                                    Accuracy    : 0.3958
# Precision   : 0.8347                                    Precision   : 0.3958
# Recall      : 0.8345                                    Recall      : 0.3861
# F1 Score    : 0.8346                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 998
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.6121                                    Loss        : 1.6237
# Accuracy    : 0.8259                                    Accuracy    : 0.3958
# Precision   : 0.8258                                    Precision   : 0.3958
# Recall      : 0.8261                                    Recall      : 0.3861
# F1 Score    : 0.8258                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 999
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.5293                                    Loss        : 1.6296
# Accuracy    : 0.8705                                    Accuracy    : 0.3958
# Precision   : 0.8713                                    Precision   : 0.3958
# Recall      : 0.8705                                    Recall      : 0.3861
# F1 Score    : 0.8705                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================
#
#
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1000
# ----------------------------------------------------------------------------------------------------
#                      TRAINING                                         VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 0.5397                                    Loss        : 1.6496
# Accuracy    : 0.8482                                    Accuracy    : 0.3958
# Precision   : 0.8451                                    Precision   : 0.3958
# Recall      : 0.8491                                    Recall      : 0.3861
# F1 Score    : 0.8465                                    F1 Score    : 0.3827
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.3529                                    FP Rate     : 0.5806
# ====================================================================================================

# %% [markdown]
# ## Ewaluacja modelu

# %%
from utils.model_functions import eval_torch_model_binary

eval_torch_model_binary(model, criterion, X_test, y_test)
# Out:
# ====================================================================================================
#                                           EPOCH STATISTICS
# ====================================================================================================
# Epoch       : 1
# ----------------------------------------------------------------------------------------------------
#                                              VALIDATION
# ----------------------------------------------------------------------------------------------------
# Loss        : 3.0837
# Accuracy    : 0.5000
# Precision   : 0.4934
# Recall      : 0.4939
# F1 Score    : 0.4857
# ----------------------------------------------------------------------------------------------------
#                                           VALIDATION EXTRA
# TP Rate     : 0.6400                                    FP Rate     : 0.6522
# ====================================================================================================

# %% [markdown]
# # TODYNET

# %% [markdown]
# ### Przygotowanie danych

# %%
X_train_np = X_train.numpy()
X_val_np = X_val.numpy()
X_test_np = X_test.numpy()
y_train_np = y_train.numpy()
y_val_np = y_val.numpy()
y_test_np = y_test.numpy()

# %%
TodyNet_DATA_PATH = os.path.join("..", "..", "src", "external", "TodyNet", "data", "UCR", "MIAMI_DECEPTION_EYE_MOVEMENT")

os.makedirs(TodyNet_DATA_PATH, exist_ok=True)

# %%
X_train_tensor = torch.tensor(X_train_np, dtype=torch.float32).unsqueeze(1)  # adding channel dimension
X_val_tensor = torch.tensor(X_val_np, dtype=torch.float32).unsqueeze(1)
X_test_tensor = torch.tensor(X_test_np, dtype=torch.float32).unsqueeze(1)

# Save the data in PyTorch (.pt) format
torch.save(X_train_tensor, os.path.join(TodyNet_DATA_PATH, 'X_train.pt'))
torch.save(X_val_tensor, os.path.join(TodyNet_DATA_PATH, 'X_valid.pt'))
torch.save(X_test_tensor, os.path.join(TodyNet_DATA_PATH, 'X.pt'))

# Save the labels in PyTorch (.pt) format
torch.save(y_train, os.path.join(TodyNet_DATA_PATH, 'y_train.pt'))
torch.save(y_val, os.path.join(TodyNet_DATA_PATH, 'y_valid.pt'))
torch.save(y_test, os.path.join(TodyNet_DATA_PATH, 'y.pt'))

# %%
X_train_tensor.shape
# Out:
# torch.Size([224, 1, 1679, 2])

# %% [markdown]
# ### Trening modelu [pool_ratio 0.8, ponieważ rozmiar danych jest zbyt duży na 0.2]

# %%
# cd .\src\external\TodyNet\src\ & python train.py --dataset='MIAMI_DECEPTION_EYE_MOVEMENT' --num_layers 1 --in_dim 16 --hidden_dim 16 --out_dim 16 --pool_ratio 0.0 --kern_size "3" --groups 1
